# %% [markdown]
# # BlazePalm

# %%
import os
import glob
import math

import cv2
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import tflite

from BlazePalmTF2.nets import blaze_palm
from BlazePalmTF2.utils.anchors_generator import AnchorsGenerator
from BlazePalmTF2.utils.loss_function import SSDLoss
from BlazePalmTF2.utils.anchor_config import AnchorsConfig

# %% [markdown]
# ## Reproduce Blaze Palm Model Structure

# %%
model = blaze_palm.build_blaze_palm_model()

# %%
tf.keras.utils.plot_model(model, 
                          to_file='nets/balze_palm_model.png', 
                          show_shapes=False, 
                          show_layer_names=True, 
                          rankdir='TB', 
                          expand_nested=False,
                          dpi=96)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# ### Check If Model Layers Are Identical to That Release by Mideapipe

# %%
buf = open('original_models/palm_detection.tflite', 'rb').read()
rel_model = tflite.Model.GetRootAsModel(buf, 0)
subgraph = rel_model.Subgraphs(0)

weights_dict = {}
weights_shape_dict = {}
rel_model_names = []

for i in range(subgraph.TensorsLength()):
    tensor = subgraph.Tensors(i)
    name = tensor.Name().decode()
    buffer_idx = tensor.Buffer()
    buffer = rel_model.Buffers(buffer_idx)

    weights_dict[name] = buffer.DataAsNumpy()
    rel_model_names.append(name)
    weights_shape_dict[name] = tensor.ShapeAsNumpy()

# %%
layer_name_list = []
layer_shape_list = []
layer_name_layer_map = {}
for layer in model.layers:
    if "conv2d" in layer.name:
        layer_name_list.append(layer.name + '/Kernel')
        layer_name_list.append(layer.name + '/Bias')
        layer_name_list.append(layer.name)
        layer_shape_list.append(layer.get_weights()[0].shape)
        layer_shape_list.append(layer.get_weights()[1].shape)
        layer_shape_list.append(layer.output_shape)
        layer_name_layer_map[layer.name] = layer
    else:
        layer_name_list.append(layer.name)
        layer_shape_list.append(layer.output_shape)

# %%
no_direct_match_model_name = [layer_name for layer_name in layer_name_list if layer_name not in weights_dict]
no_direct_match_rel_model_name = [layer_name for layer_name in weights_dict if layer_name not in layer_name_list]

# %%
for i in range(len(rel_model_names)):
    print(
        rel_model_names[i].ljust(50), 
        str(weights_shape_dict[rel_model_names[i]]).ljust(20), 
        layer_name_list[i].ljust(50), 
        str(layer_shape_list[i]).ljust(20), 
        rel_model_names[i] in no_direct_match_rel_model_name,  
        layer_name_list[i] in no_direct_match_model_name
        )
# Out:
# input                                              [  1 256 256   3]    input_1                                            [(1, 256, 256, 3)]   True True
# conv2d/Kernel                                      [32  3  3  3]        conv2d/Kernel                                      (3, 3, 3, 32)        False False
# conv2d/Bias                                        [32]                 conv2d/Bias                                        (32,)                False False
# conv2d                                             [  1 128 128  32]    conv2d                                             (1, 128, 128, 32)    False False
# activation                                         [  1 128 128  32]    activation                                         (1, 128, 128, 32)    False False
# depthwise_conv2d/Kernel                            [ 1  3  3 32]        depthwise_conv2d/Kernel                            (3, 3, 32, 1)        False False
# depthwise_conv2d/Bias                              [32]                 depthwise_conv2d/Bias                              (32,)                False False
# depthwise_conv2d                                   [  1 128 128  32]    depthwise_conv2d                                   (1, 128, 128, 32)    False False
# conv2d_1/Kernel                                    [32  1  1 32]        conv2d_1/Kernel                                    (1, 1, 32, 32)       False False
# conv2d_1/Bias                                      [32]                 conv2d_1/Bias                                      (32,)                False False
# conv2d_1                                           [  1 128 128  32]    conv2d_1                                           (1, 128, 128, 32)    False False
# add                                                [  1 128 128  32]    add                                                (1, 128, 128, 32)    False False
# activation_1                                       [  1 128 128  32]    activation_1                                       (1, 128, 128, 32)    False False
# depthwise_conv2d_1/Kernel                          [ 1  3  3 32]        depthwise_conv2d_1/Kernel                          (3, 3, 32, 1)        False False
# depthwise_conv2d_1/Bias                            [32]                 depthwise_conv2d_1/Bias                            (32,)                False False
# depthwise_conv2d_1                                 [  1 128 128  32]    depthwise_conv2d_1                                 (1, 128, 128, 32)    False False
# conv2d_2/Kernel                                    [32  1  1 32]        conv2d_2/Kernel                                    (1, 1, 32, 32)       False False
# conv2d_2/Bias                                      [32]                 conv2d_2/Bias                                      (32,)                False False
# conv2d_2                                           [  1 128 128  32]    conv2d_2                                           (1, 128, 128, 32)    False False
# add_1                                              [  1 128 128  32]    add_1                                              (1, 128, 128, 32)    False False
# activation_2                                       [  1 128 128  32]    activation_2                                       (1, 128, 128, 32)    False False
# depthwise_conv2d_2/Kernel                          [ 1  3  3 32]        depthwise_conv2d_2/Kernel                          (3, 3, 32, 1)        False False
# depthwise_conv2d_2/Bias                            [32]                 depthwise_conv2d_2/Bias                            (32,)                False False
# depthwise_conv2d_2                                 [  1 128 128  32]    depthwise_conv2d_2                                 (1, 128, 128, 32)    False False
# conv2d_3/Kernel                                    [32  1  1 32]        conv2d_3/Kernel                                    (1, 1, 32, 32)       False False
# conv2d_3/Bias                                      [32]                 conv2d_3/Bias                                      (32,)                False False
# conv2d_3                                           [  1 128 128  32]    conv2d_3                                           (1, 128, 128, 32)    False False
# add_2                                              [  1 128 128  32]    add_2                                              (1, 128, 128, 32)    False False
# activation_3                                       [  1 128 128  32]    activation_3                                       (1, 128, 128, 32)    False False
# depthwise_conv2d_3/Kernel                          [ 1  3  3 32]        depthwise_conv2d_3/Kernel                          (3, 3, 32, 1)        False False
# depthwise_conv2d_3/Bias                            [32]                 depthwise_conv2d_3/Bias                            (32,)                False False
# depthwise_conv2d_3                                 [  1 128 128  32]    depthwise_conv2d_3                                 (1, 128, 128, 32)    False False
# conv2d_4/Kernel                                    [32  1  1 32]        conv2d_4/Kernel                                    (1, 1, 32, 32)       False False
# conv2d_4/Bias                                      [32]                 conv2d_4/Bias                                      (32,)                False False
# conv2d_4                                           [  1 128 128  32]    conv2d_4                                           (1, 128, 128, 32)    False False
# add_3                                              [  1 128 128  32]    add_3                                              (1, 128, 128, 32)    False False
# activation_4                                       [  1 128 128  32]    activation_4                                       (1, 128, 128, 32)    False False
# depthwise_conv2d_4/Kernel                          [ 1  3  3 32]        depthwise_conv2d_4/Kernel                          (3, 3, 32, 1)        False False
# depthwise_conv2d_4/Bias                            [32]                 depthwise_conv2d_4/Bias                            (32,)                False False
# depthwise_conv2d_4                                 [  1 128 128  32]    depthwise_conv2d_4                                 (1, 128, 128, 32)    False False
# conv2d_5/Kernel                                    [32  1  1 32]        conv2d_5/Kernel                                    (1, 1, 32, 32)       False False
# conv2d_5/Bias                                      [32]                 conv2d_5/Bias                                      (32,)                False False
# conv2d_5                                           [  1 128 128  32]    conv2d_5                                           (1, 128, 128, 32)    False False
# add_4                                              [  1 128 128  32]    add_4                                              (1, 128, 128, 32)    False False
# activation_5                                       [  1 128 128  32]    activation_5                                       (1, 128, 128, 32)    False False
# depthwise_conv2d_5/Kernel                          [ 1  3  3 32]        depthwise_conv2d_5/Kernel                          (3, 3, 32, 1)        False False
# depthwise_conv2d_5/Bias                            [32]                 depthwise_conv2d_5/Bias                            (32,)                False False
# depthwise_conv2d_5                                 [  1 128 128  32]    depthwise_conv2d_5                                 (1, 128, 128, 32)    False False
# conv2d_6/Kernel                                    [32  1  1 32]        conv2d_6/Kernel                                    (1, 1, 32, 32)       False False
# conv2d_6/Bias                                      [32]                 conv2d_6/Bias                                      (32,)                False False
# conv2d_6                                           [  1 128 128  32]    conv2d_6                                           (1, 128, 128, 32)    False False
# add_5                                              [  1 128 128  32]    add_5                                              (1, 128, 128, 32)    False False
# activation_6                                       [  1 128 128  32]    activation_6                                       (1, 128, 128, 32)    False False
# depthwise_conv2d_6/Kernel                          [ 1  3  3 32]        depthwise_conv2d_6/Kernel                          (3, 3, 32, 1)        False False
# depthwise_conv2d_6/Bias                            [32]                 depthwise_conv2d_6/Bias                            (32,)                False False
# depthwise_conv2d_6                                 [  1 128 128  32]    depthwise_conv2d_6                                 (1, 128, 128, 32)    False False
# conv2d_7/Kernel                                    [32  1  1 32]        conv2d_7/Kernel                                    (1, 1, 32, 32)       False False
# conv2d_7/Bias                                      [32]                 conv2d_7/Bias                                      (32,)                False False
# conv2d_7                                           [  1 128 128  32]    conv2d_7                                           (1, 128, 128, 32)    False False
# add_6                                              [  1 128 128  32]    add_6                                              (1, 128, 128, 32)    False False
# activation_7                                       [  1 128 128  32]    activation_7                                       (1, 128, 128, 32)    False False
# depthwise_conv2d_7/Kernel                          [ 1  3  3 32]        max_pooling2d                                      (1, 64, 64, 32)      False False
# depthwise_conv2d_7/Bias                            [32]                 depthwise_conv2d_7/Kernel                          (3, 3, 32, 1)        False False
# depthwise_conv2d_7                                 [ 1 64 64 32]        depthwise_conv2d_7/Bias                            (32,)                False False
# max_pooling2d                                      [ 1 64 64 32]        depthwise_conv2d_7                                 (1, 64, 64, 32)      False False
# conv2d_8/Kernel                                    [64  1  1 32]        tf.zeros_like                                      (1, 64, 64, 32)      False True
# conv2d_8/Bias                                      [64]                 conv2d_8/Kernel                                    (1, 1, 32, 64)       False False
# conv2d_8                                           [ 1 64 64 64]        conv2d_8/Bias                                      (64,)                False False
# channel_padding/Paddings                           [4 2]                conv2d_8                                           (1, 64, 64, 64)      True False
# channel_padding                                    [ 1 64 64 64]        tf.concat                                          (1, 64, 64, 64)      True True
# add_7                                              [ 1 64 64 64]        add_7                                              (1, 64, 64, 64)      False False
# activation_8                                       [ 1 64 64 64]        activation_8                                       (1, 64, 64, 64)      False False
# depthwise_conv2d_8/Kernel                          [ 1  3  3 64]        depthwise_conv2d_8/Kernel                          (3, 3, 64, 1)        False False
# depthwise_conv2d_8/Bias                            [64]                 depthwise_conv2d_8/Bias                            (64,)                False False
# depthwise_conv2d_8                                 [ 1 64 64 64]        depthwise_conv2d_8                                 (1, 64, 64, 64)      False False
# conv2d_9/Kernel                                    [64  1  1 64]        conv2d_9/Kernel                                    (1, 1, 64, 64)       False False
# conv2d_9/Bias                                      [64]                 conv2d_9/Bias                                      (64,)                False False
# conv2d_9                                           [ 1 64 64 64]        conv2d_9                                           (1, 64, 64, 64)      False False
# add_8                                              [ 1 64 64 64]        add_8                                              (1, 64, 64, 64)      False False
# activation_9                                       [ 1 64 64 64]        activation_9                                       (1, 64, 64, 64)      False False
# depthwise_conv2d_9/Kernel                          [ 1  3  3 64]        depthwise_conv2d_9/Kernel                          (3, 3, 64, 1)        False False
# depthwise_conv2d_9/Bias                            [64]                 depthwise_conv2d_9/Bias                            (64,)                False False
# depthwise_conv2d_9                                 [ 1 64 64 64]        depthwise_conv2d_9                                 (1, 64, 64, 64)      False False
# conv2d_10/Kernel                                   [64  1  1 64]        conv2d_10/Kernel                                   (1, 1, 64, 64)       False False
# conv2d_10/Bias                                     [64]                 conv2d_10/Bias                                     (64,)                False False
# conv2d_10                                          [ 1 64 64 64]        conv2d_10                                          (1, 64, 64, 64)      False False
# add_9                                              [ 1 64 64 64]        add_9                                              (1, 64, 64, 64)      False False
# activation_10                                      [ 1 64 64 64]        activation_10                                      (1, 64, 64, 64)      False False
# depthwise_conv2d_10/Kernel                         [ 1  3  3 64]        depthwise_conv2d_10/Kernel                         (3, 3, 64, 1)        False False
# depthwise_conv2d_10/Bias                           [64]                 depthwise_conv2d_10/Bias                           (64,)                False False
# depthwise_conv2d_10                                [ 1 64 64 64]        depthwise_conv2d_10                                (1, 64, 64, 64)      False False
# conv2d_11/Kernel                                   [64  1  1 64]        conv2d_11/Kernel                                   (1, 1, 64, 64)       False False
# conv2d_11/Bias                                     [64]                 conv2d_11/Bias                                     (64,)                False False
# conv2d_11                                          [ 1 64 64 64]        conv2d_11                                          (1, 64, 64, 64)      False False
# add_10                                             [ 1 64 64 64]        add_10                                             (1, 64, 64, 64)      False False
# activation_11                                      [ 1 64 64 64]        activation_11                                      (1, 64, 64, 64)      False False
# depthwise_conv2d_11/Kernel                         [ 1  3  3 64]        depthwise_conv2d_11/Kernel                         (3, 3, 64, 1)        False False
# depthwise_conv2d_11/Bias                           [64]                 depthwise_conv2d_11/Bias                           (64,)                False False
# depthwise_conv2d_11                                [ 1 64 64 64]        depthwise_conv2d_11                                (1, 64, 64, 64)      False False
# conv2d_12/Kernel                                   [64  1  1 64]        conv2d_12/Kernel                                   (1, 1, 64, 64)       False False
# conv2d_12/Bias                                     [64]                 conv2d_12/Bias                                     (64,)                False False
# conv2d_12                                          [ 1 64 64 64]        conv2d_12                                          (1, 64, 64, 64)      False False
# add_11                                             [ 1 64 64 64]        add_11                                             (1, 64, 64, 64)      False False
# activation_12                                      [ 1 64 64 64]        activation_12                                      (1, 64, 64, 64)      False False
# depthwise_conv2d_12/Kernel                         [ 1  3  3 64]        depthwise_conv2d_12/Kernel                         (3, 3, 64, 1)        False False
# depthwise_conv2d_12/Bias                           [64]                 depthwise_conv2d_12/Bias                           (64,)                False False
# depthwise_conv2d_12                                [ 1 64 64 64]        depthwise_conv2d_12                                (1, 64, 64, 64)      False False
# conv2d_13/Kernel                                   [64  1  1 64]        conv2d_13/Kernel                                   (1, 1, 64, 64)       False False
# conv2d_13/Bias                                     [64]                 conv2d_13/Bias                                     (64,)                False False
# conv2d_13                                          [ 1 64 64 64]        conv2d_13                                          (1, 64, 64, 64)      False False
# add_12                                             [ 1 64 64 64]        add_12                                             (1, 64, 64, 64)      False False
# activation_13                                      [ 1 64 64 64]        activation_13                                      (1, 64, 64, 64)      False False
# depthwise_conv2d_13/Kernel                         [ 1  3  3 64]        depthwise_conv2d_13/Kernel                         (3, 3, 64, 1)        False False
# depthwise_conv2d_13/Bias                           [64]                 depthwise_conv2d_13/Bias                           (64,)                False False
# depthwise_conv2d_13                                [ 1 64 64 64]        depthwise_conv2d_13                                (1, 64, 64, 64)      False False
# conv2d_14/Kernel                                   [64  1  1 64]        conv2d_14/Kernel                                   (1, 1, 64, 64)       False False
# conv2d_14/Bias                                     [64]                 conv2d_14/Bias                                     (64,)                False False
# conv2d_14                                          [ 1 64 64 64]        conv2d_14                                          (1, 64, 64, 64)      False False
# add_13                                             [ 1 64 64 64]        add_13                                             (1, 64, 64, 64)      False False
# activation_14                                      [ 1 64 64 64]        activation_14                                      (1, 64, 64, 64)      False False
# depthwise_conv2d_14/Kernel                         [ 1  3  3 64]        depthwise_conv2d_14/Kernel                         (3, 3, 64, 1)        False False
# depthwise_conv2d_14/Bias                           [64]                 depthwise_conv2d_14/Bias                           (64,)                False False
# depthwise_conv2d_14                                [ 1 64 64 64]        depthwise_conv2d_14                                (1, 64, 64, 64)      False False
# conv2d_15/Kernel                                   [64  1  1 64]        conv2d_15/Kernel                                   (1, 1, 64, 64)       False False
# conv2d_15/Bias                                     [64]                 conv2d_15/Bias                                     (64,)                False False
# conv2d_15                                          [ 1 64 64 64]        conv2d_15                                          (1, 64, 64, 64)      False False
# add_14                                             [ 1 64 64 64]        add_14                                             (1, 64, 64, 64)      False False
# activation_15                                      [ 1 64 64 64]        activation_15                                      (1, 64, 64, 64)      False False
# depthwise_conv2d_15/Kernel                         [ 1  3  3 64]        max_pooling2d_1                                    (1, 32, 32, 64)      False False
# depthwise_conv2d_15/Bias                           [64]                 depthwise_conv2d_15/Kernel                         (3, 3, 64, 1)        False False
# depthwise_conv2d_15                                [ 1 32 32 64]        depthwise_conv2d_15/Bias                           (64,)                False False
# max_pooling2d_1                                    [ 1 32 32 64]        depthwise_conv2d_15                                (1, 32, 32, 64)      False False
# conv2d_16/Kernel                                   [128   1   1  64]    tf.zeros_like_1                                    (1, 32, 32, 64)      False True
# conv2d_16/Bias                                     [128]                conv2d_16/Kernel                                   (1, 1, 64, 128)      False False
# conv2d_16                                          [  1  32  32 128]    conv2d_16/Bias                                     (128,)               False False
# channel_padding_1/Paddings                         [4 2]                conv2d_16                                          (1, 32, 32, 128)     True False
# channel_padding_1                                  [  1  32  32 128]    tf.concat_1                                        (1, 32, 32, 128)     True True
# add_15                                             [  1  32  32 128]    add_15                                             (1, 32, 32, 128)     False False
# activation_16                                      [  1  32  32 128]    activation_16                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_16/Kernel                         [  1   3   3 128]    depthwise_conv2d_16/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_16/Bias                           [128]                depthwise_conv2d_16/Bias                           (128,)               False False
# depthwise_conv2d_16                                [  1  32  32 128]    depthwise_conv2d_16                                (1, 32, 32, 128)     False False
# conv2d_17/Kernel                                   [128   1   1 128]    conv2d_17/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_17/Bias                                     [128]                conv2d_17/Bias                                     (128,)               False False
# conv2d_17                                          [  1  32  32 128]    conv2d_17                                          (1, 32, 32, 128)     False False
# add_16                                             [  1  32  32 128]    add_16                                             (1, 32, 32, 128)     False False
# activation_17                                      [  1  32  32 128]    activation_17                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_17/Kernel                         [  1   3   3 128]    depthwise_conv2d_17/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_17/Bias                           [128]                depthwise_conv2d_17/Bias                           (128,)               False False
# depthwise_conv2d_17                                [  1  32  32 128]    depthwise_conv2d_17                                (1, 32, 32, 128)     False False
# conv2d_18/Kernel                                   [128   1   1 128]    conv2d_18/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_18/Bias                                     [128]                conv2d_18/Bias                                     (128,)               False False
# conv2d_18                                          [  1  32  32 128]    conv2d_18                                          (1, 32, 32, 128)     False False
# add_17                                             [  1  32  32 128]    add_17                                             (1, 32, 32, 128)     False False
# activation_18                                      [  1  32  32 128]    activation_18                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_18/Kernel                         [  1   3   3 128]    depthwise_conv2d_18/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_18/Bias                           [128]                depthwise_conv2d_18/Bias                           (128,)               False False
# depthwise_conv2d_18                                [  1  32  32 128]    depthwise_conv2d_18                                (1, 32, 32, 128)     False False
# conv2d_19/Kernel                                   [128   1   1 128]    conv2d_19/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_19/Bias                                     [128]                conv2d_19/Bias                                     (128,)               False False
# conv2d_19                                          [  1  32  32 128]    conv2d_19                                          (1, 32, 32, 128)     False False
# add_18                                             [  1  32  32 128]    add_18                                             (1, 32, 32, 128)     False False
# activation_19                                      [  1  32  32 128]    activation_19                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_19/Kernel                         [  1   3   3 128]    depthwise_conv2d_19/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_19/Bias                           [128]                depthwise_conv2d_19/Bias                           (128,)               False False
# depthwise_conv2d_19                                [  1  32  32 128]    depthwise_conv2d_19                                (1, 32, 32, 128)     False False
# conv2d_20/Kernel                                   [128   1   1 128]    conv2d_20/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_20/Bias                                     [128]                conv2d_20/Bias                                     (128,)               False False
# conv2d_20                                          [  1  32  32 128]    conv2d_20                                          (1, 32, 32, 128)     False False
# add_19                                             [  1  32  32 128]    add_19                                             (1, 32, 32, 128)     False False
# activation_20                                      [  1  32  32 128]    activation_20                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_20/Kernel                         [  1   3   3 128]    depthwise_conv2d_20/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_20/Bias                           [128]                depthwise_conv2d_20/Bias                           (128,)               False False
# depthwise_conv2d_20                                [  1  32  32 128]    depthwise_conv2d_20                                (1, 32, 32, 128)     False False
# conv2d_21/Kernel                                   [128   1   1 128]    conv2d_21/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_21/Bias                                     [128]                conv2d_21/Bias                                     (128,)               False False
# conv2d_21                                          [  1  32  32 128]    conv2d_21                                          (1, 32, 32, 128)     False False
# add_20                                             [  1  32  32 128]    add_20                                             (1, 32, 32, 128)     False False
# activation_21                                      [  1  32  32 128]    activation_21                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_21/Kernel                         [  1   3   3 128]    depthwise_conv2d_21/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_21/Bias                           [128]                depthwise_conv2d_21/Bias                           (128,)               False False
# depthwise_conv2d_21                                [  1  32  32 128]    depthwise_conv2d_21                                (1, 32, 32, 128)     False False
# conv2d_22/Kernel                                   [128   1   1 128]    conv2d_22/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_22/Bias                                     [128]                conv2d_22/Bias                                     (128,)               False False
# conv2d_22                                          [  1  32  32 128]    conv2d_22                                          (1, 32, 32, 128)     False False
# add_21                                             [  1  32  32 128]    add_21                                             (1, 32, 32, 128)     False False
# activation_22                                      [  1  32  32 128]    activation_22                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_22/Kernel                         [  1   3   3 128]    depthwise_conv2d_22/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_22/Bias                           [128]                depthwise_conv2d_22/Bias                           (128,)               False False
# depthwise_conv2d_22                                [  1  32  32 128]    depthwise_conv2d_22                                (1, 32, 32, 128)     False False
# conv2d_23/Kernel                                   [128   1   1 128]    conv2d_23/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_23/Bias                                     [128]                conv2d_23/Bias                                     (128,)               False False
# conv2d_23                                          [  1  32  32 128]    conv2d_23                                          (1, 32, 32, 128)     False False
# add_22                                             [  1  32  32 128]    add_22                                             (1, 32, 32, 128)     False False
# activation_23                                      [  1  32  32 128]    activation_23                                      (1, 32, 32, 128)     False False
# depthwise_conv2d_23/Kernel                         [  1   3   3 128]    max_pooling2d_2                                    (1, 16, 16, 128)     False False
# depthwise_conv2d_23/Bias                           [128]                depthwise_conv2d_23/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_23                                [  1  16  16 128]    depthwise_conv2d_23/Bias                           (128,)               False False
# max_pooling2d_2                                    [  1  16  16 128]    depthwise_conv2d_23                                (1, 16, 16, 128)     False False
# conv2d_24/Kernel                                   [256   1   1 128]    tf.zeros_like_2                                    (1, 16, 16, 128)     False True
# conv2d_24/Bias                                     [256]                conv2d_24/Kernel                                   (1, 1, 128, 256)     False False
# conv2d_24                                          [  1  16  16 256]    conv2d_24/Bias                                     (256,)               False False
# channel_padding_2/Paddings                         [4 2]                conv2d_24                                          (1, 16, 16, 256)     True False
# channel_padding_2                                  [  1  16  16 256]    tf.concat_2                                        (1, 16, 16, 256)     True True
# add_23                                             [  1  16  16 256]    add_23                                             (1, 16, 16, 256)     False False
# activation_24                                      [  1  16  16 256]    activation_24                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_24/Kernel                         [  1   3   3 256]    depthwise_conv2d_24/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_24/Bias                           [256]                depthwise_conv2d_24/Bias                           (256,)               False False
# depthwise_conv2d_24                                [  1  16  16 256]    depthwise_conv2d_24                                (1, 16, 16, 256)     False False
# conv2d_25/Kernel                                   [256   1   1 256]    conv2d_25/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_25/Bias                                     [256]                conv2d_25/Bias                                     (256,)               False False
# conv2d_25                                          [  1  16  16 256]    conv2d_25                                          (1, 16, 16, 256)     False False
# add_24                                             [  1  16  16 256]    add_24                                             (1, 16, 16, 256)     False False
# activation_25                                      [  1  16  16 256]    activation_25                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_25/Kernel                         [  1   3   3 256]    depthwise_conv2d_25/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_25/Bias                           [256]                depthwise_conv2d_25/Bias                           (256,)               False False
# depthwise_conv2d_25                                [  1  16  16 256]    depthwise_conv2d_25                                (1, 16, 16, 256)     False False
# conv2d_26/Kernel                                   [256   1   1 256]    conv2d_26/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_26/Bias                                     [256]                conv2d_26/Bias                                     (256,)               False False
# conv2d_26                                          [  1  16  16 256]    conv2d_26                                          (1, 16, 16, 256)     False False
# add_25                                             [  1  16  16 256]    add_25                                             (1, 16, 16, 256)     False False
# activation_26                                      [  1  16  16 256]    activation_26                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_26/Kernel                         [  1   3   3 256]    depthwise_conv2d_26/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_26/Bias                           [256]                depthwise_conv2d_26/Bias                           (256,)               False False
# depthwise_conv2d_26                                [  1  16  16 256]    depthwise_conv2d_26                                (1, 16, 16, 256)     False False
# conv2d_27/Kernel                                   [256   1   1 256]    conv2d_27/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_27/Bias                                     [256]                conv2d_27/Bias                                     (256,)               False False
# conv2d_27                                          [  1  16  16 256]    conv2d_27                                          (1, 16, 16, 256)     False False
# add_26                                             [  1  16  16 256]    add_26                                             (1, 16, 16, 256)     False False
# activation_27                                      [  1  16  16 256]    activation_27                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_27/Kernel                         [  1   3   3 256]    depthwise_conv2d_27/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_27/Bias                           [256]                depthwise_conv2d_27/Bias                           (256,)               False False
# depthwise_conv2d_27                                [  1  16  16 256]    depthwise_conv2d_27                                (1, 16, 16, 256)     False False
# conv2d_28/Kernel                                   [256   1   1 256]    conv2d_28/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_28/Bias                                     [256]                conv2d_28/Bias                                     (256,)               False False
# conv2d_28                                          [  1  16  16 256]    conv2d_28                                          (1, 16, 16, 256)     False False
# add_27                                             [  1  16  16 256]    add_27                                             (1, 16, 16, 256)     False False
# activation_28                                      [  1  16  16 256]    activation_28                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_28/Kernel                         [  1   3   3 256]    depthwise_conv2d_28/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_28/Bias                           [256]                depthwise_conv2d_28/Bias                           (256,)               False False
# depthwise_conv2d_28                                [  1  16  16 256]    depthwise_conv2d_28                                (1, 16, 16, 256)     False False
# conv2d_29/Kernel                                   [256   1   1 256]    conv2d_29/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_29/Bias                                     [256]                conv2d_29/Bias                                     (256,)               False False
# conv2d_29                                          [  1  16  16 256]    conv2d_29                                          (1, 16, 16, 256)     False False
# add_28                                             [  1  16  16 256]    add_28                                             (1, 16, 16, 256)     False False
# activation_29                                      [  1  16  16 256]    activation_29                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_29/Kernel                         [  1   3   3 256]    depthwise_conv2d_29/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_29/Bias                           [256]                depthwise_conv2d_29/Bias                           (256,)               False False
# depthwise_conv2d_29                                [  1  16  16 256]    depthwise_conv2d_29                                (1, 16, 16, 256)     False False
# conv2d_30/Kernel                                   [256   1   1 256]    conv2d_30/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_30/Bias                                     [256]                conv2d_30/Bias                                     (256,)               False False
# conv2d_30                                          [  1  16  16 256]    conv2d_30                                          (1, 16, 16, 256)     False False
# add_29                                             [  1  16  16 256]    add_29                                             (1, 16, 16, 256)     False False
# activation_30                                      [  1  16  16 256]    activation_30                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_30/Kernel                         [  1   3   3 256]    depthwise_conv2d_30/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_30/Bias                           [256]                depthwise_conv2d_30/Bias                           (256,)               False False
# depthwise_conv2d_30                                [  1  16  16 256]    depthwise_conv2d_30                                (1, 16, 16, 256)     False False
# conv2d_31/Kernel                                   [256   1   1 256]    conv2d_31/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_31/Bias                                     [256]                conv2d_31/Bias                                     (256,)               False False
# conv2d_31                                          [  1  16  16 256]    conv2d_31                                          (1, 16, 16, 256)     False False
# add_30                                             [  1  16  16 256]    add_30                                             (1, 16, 16, 256)     False False
# activation_31                                      [  1  16  16 256]    activation_31                                      (1, 16, 16, 256)     False False
# depthwise_conv2d_31/Kernel                         [  1   3   3 256]    depthwise_conv2d_31/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_31/Bias                           [256]                depthwise_conv2d_31/Bias                           (256,)               False False
# depthwise_conv2d_31                                [  1   8   8 256]    depthwise_conv2d_31                                (1, 8, 8, 256)       False False
# conv2d_32/Kernel                                   [256   1   1 256]    conv2d_32/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_32/Bias                                     [256]                conv2d_32/Bias                                     (256,)               False False
# conv2d_32                                          [  1   8   8 256]    conv2d_32                                          (1, 8, 8, 256)       False False
# max_pooling2d_3                                    [  1   8   8 256]    max_pooling2d_3                                    (1, 8, 8, 256)       False False
# add_31                                             [  1   8   8 256]    add_31                                             (1, 8, 8, 256)       False False
# activation_32                                      [  1   8   8 256]    activation_32                                      (1, 8, 8, 256)       False False
# depthwise_conv2d_32/Kernel                         [  1   3   3 256]    depthwise_conv2d_32/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_32/Bias                           [256]                depthwise_conv2d_32/Bias                           (256,)               False False
# depthwise_conv2d_32                                [  1   8   8 256]    depthwise_conv2d_32                                (1, 8, 8, 256)       False False
# conv2d_33/Kernel                                   [256   1   1 256]    conv2d_33/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_33/Bias                                     [256]                conv2d_33/Bias                                     (256,)               False False
# conv2d_33                                          [  1   8   8 256]    conv2d_33                                          (1, 8, 8, 256)       False False
# add_32                                             [  1   8   8 256]    add_32                                             (1, 8, 8, 256)       False False
# activation_33                                      [  1   8   8 256]    activation_33                                      (1, 8, 8, 256)       False False
# depthwise_conv2d_33/Kernel                         [  1   3   3 256]    depthwise_conv2d_33/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_33/Bias                           [256]                depthwise_conv2d_33/Bias                           (256,)               False False
# depthwise_conv2d_33                                [  1   8   8 256]    depthwise_conv2d_33                                (1, 8, 8, 256)       False False
# conv2d_34/Kernel                                   [256   1   1 256]    conv2d_34/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_34/Bias                                     [256]                conv2d_34/Bias                                     (256,)               False False
# conv2d_34                                          [  1   8   8 256]    conv2d_34                                          (1, 8, 8, 256)       False False
# add_33                                             [  1   8   8 256]    add_33                                             (1, 8, 8, 256)       False False
# activation_34                                      [  1   8   8 256]    activation_34                                      (1, 8, 8, 256)       False False
# depthwise_conv2d_34/Kernel                         [  1   3   3 256]    depthwise_conv2d_34/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_34/Bias                           [256]                depthwise_conv2d_34/Bias                           (256,)               False False
# depthwise_conv2d_34                                [  1   8   8 256]    depthwise_conv2d_34                                (1, 8, 8, 256)       False False
# conv2d_35/Kernel                                   [256   1   1 256]    conv2d_35/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_35/Bias                                     [256]                conv2d_35/Bias                                     (256,)               False False
# conv2d_35                                          [  1   8   8 256]    conv2d_35                                          (1, 8, 8, 256)       False False
# add_34                                             [  1   8   8 256]    add_34                                             (1, 8, 8, 256)       False False
# activation_35                                      [  1   8   8 256]    activation_35                                      (1, 8, 8, 256)       False False
# depthwise_conv2d_35/Kernel                         [  1   3   3 256]    depthwise_conv2d_35/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_35/Bias                           [256]                depthwise_conv2d_35/Bias                           (256,)               False False
# depthwise_conv2d_35                                [  1   8   8 256]    depthwise_conv2d_35                                (1, 8, 8, 256)       False False
# conv2d_36/Kernel                                   [256   1   1 256]    conv2d_36/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_36/Bias                                     [256]                conv2d_36/Bias                                     (256,)               False False
# conv2d_36                                          [  1   8   8 256]    conv2d_36                                          (1, 8, 8, 256)       False False
# add_35                                             [  1   8   8 256]    add_35                                             (1, 8, 8, 256)       False False
# activation_36                                      [  1   8   8 256]    activation_36                                      (1, 8, 8, 256)       False False
# depthwise_conv2d_36/Kernel                         [  1   3   3 256]    depthwise_conv2d_36/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_36/Bias                           [256]                depthwise_conv2d_36/Bias                           (256,)               False False
# depthwise_conv2d_36                                [  1   8   8 256]    depthwise_conv2d_36                                (1, 8, 8, 256)       False False
# conv2d_37/Kernel                                   [256   1   1 256]    conv2d_37/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_37/Bias                                     [256]                conv2d_37/Bias                                     (256,)               False False
# conv2d_37                                          [  1   8   8 256]    conv2d_37                                          (1, 8, 8, 256)       False False
# add_36                                             [  1   8   8 256]    add_36                                             (1, 8, 8, 256)       False False
# activation_37                                      [  1   8   8 256]    activation_37                                      (1, 8, 8, 256)       False False
# depthwise_conv2d_37/Kernel                         [  1   3   3 256]    depthwise_conv2d_37/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_37/Bias                           [256]                depthwise_conv2d_37/Bias                           (256,)               False False
# depthwise_conv2d_37                                [  1   8   8 256]    depthwise_conv2d_37                                (1, 8, 8, 256)       False False
# conv2d_38/Kernel                                   [256   1   1 256]    conv2d_38/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_38/Bias                                     [256]                conv2d_38/Bias                                     (256,)               False False
# conv2d_38                                          [  1   8   8 256]    conv2d_38                                          (1, 8, 8, 256)       False False
# add_37                                             [  1   8   8 256]    add_37                                             (1, 8, 8, 256)       False False
# activation_38                                      [  1   8   8 256]    activation_38                                      (1, 8, 8, 256)       False False
# depthwise_conv2d_38/Kernel                         [  1   3   3 256]    depthwise_conv2d_38/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_38/Bias                           [256]                depthwise_conv2d_38/Bias                           (256,)               False False
# depthwise_conv2d_38                                [  1   8   8 256]    depthwise_conv2d_38                                (1, 8, 8, 256)       False False
# conv2d_39/Kernel                                   [256   1   1 256]    conv2d_39/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_39/Bias                                     [256]                conv2d_39/Bias                                     (256,)               False False
# conv2d_39                                          [  1   8   8 256]    conv2d_39                                          (1, 8, 8, 256)       False False
# add_38                                             [  1   8   8 256]    add_38                                             (1, 8, 8, 256)       False False
# activation_39                                      [  1   8   8 256]    activation_39                                      (1, 8, 8, 256)       False False
# conv2d_transpose/Kernel                            [256   2   2 256]    conv2d_transpose/Kernel                            (2, 2, 256, 256)     False False
# conv2d_transpose/Bias                              [256]                conv2d_transpose/Bias                              (256,)               False False
# conv2d_transpose                                   [  1  16  16 256]    conv2d_transpose                                   (1, 16, 16, 256)     False False
# activation_40                                      [  1  16  16 256]    activation_40                                      (1, 16, 16, 256)     False False
# add_39                                             [  1  16  16 256]    add_39                                             (1, 16, 16, 256)     False False
# depthwise_conv2d_39/Kernel                         [  1   3   3 256]    depthwise_conv2d_39/Kernel                         (3, 3, 256, 1)       False False
# depthwise_conv2d_39/Bias                           [256]                depthwise_conv2d_39/Bias                           (256,)               False False
# depthwise_conv2d_39                                [  1  16  16 256]    depthwise_conv2d_39                                (1, 16, 16, 256)     False False
# conv2d_40/Kernel                                   [256   1   1 256]    conv2d_40/Kernel                                   (1, 1, 256, 256)     False False
# conv2d_40/Bias                                     [256]                conv2d_40/Bias                                     (256,)               False False
# conv2d_40                                          [  1  16  16 256]    conv2d_40                                          (1, 16, 16, 256)     False False
# add_40                                             [  1  16  16 256]    add_40                                             (1, 16, 16, 256)     False False
# activation_41                                      [  1  16  16 256]    activation_41                                      (1, 16, 16, 256)     False False
# conv2d_transpose_1/Kernel                          [128   2   2 256]    conv2d_transpose_1/Kernel                          (2, 2, 128, 256)     False False
# conv2d_transpose_1/Bias                            [128]                conv2d_transpose_1/Bias                            (128,)               False False
# conv2d_transpose_1                                 [  1  32  32 128]    conv2d_transpose_1                                 (1, 32, 32, 128)     False False
# activation_42                                      [  1  32  32 128]    activation_42                                      (1, 32, 32, 128)     False False
# add_41                                             [  1  32  32 128]    add_41                                             (1, 32, 32, 128)     False False
# depthwise_conv2d_40/Kernel                         [  1   3   3 128]    depthwise_conv2d_40/Kernel                         (3, 3, 128, 1)       False False
# depthwise_conv2d_40/Bias                           [128]                depthwise_conv2d_40/Bias                           (128,)               False False
# depthwise_conv2d_40                                [  1  32  32 128]    depthwise_conv2d_40                                (1, 32, 32, 128)     False False
# conv2d_41/Kernel                                   [128   1   1 128]    conv2d_41/Kernel                                   (1, 1, 128, 128)     False False
# conv2d_41/Bias                                     [128]                conv2d_41/Bias                                     (128,)               False False
# conv2d_41                                          [  1  32  32 128]    conv2d_41                                          (1, 32, 32, 128)     False False
# add_42                                             [  1  32  32 128]    add_42                                             (1, 32, 32, 128)     False False
# activation_43                                      [  1  32  32 128]    activation_43                                      (1, 32, 32, 128)     False False
# classificator_8/Kernel                             [  2   1   1 128]    conv2d_45/Kernel                                   (1, 1, 128, 2)       True True
# classificator_8/Bias                               [2]                  conv2d_45/Bias                                     (2,)                 True True
# classificator_8                                    [ 1 32 32  2]        conv2d_45                                          (1, 32, 32, 2)       True True
# classificator_16/Kernel                            [  2   1   1 256]    conv2d_46/Kernel                                   (1, 1, 256, 2)       True True
# classificator_16/Bias                              [2]                  conv2d_46/Bias                                     (2,)                 True True
# classificator_16                                   [ 1 16 16  2]        conv2d_46                                          (1, 16, 16, 2)       True True
# classificator_32/Kernel                            [  6   1   1 256]    conv2d_47/Kernel                                   (1, 1, 256, 6)       True True
# classificator_32/Bias                              [6]                  conv2d_47/Bias                                     (6,)                 True True
# classificator_32                                   [1 8 8 6]            conv2d_47                                          (1, 8, 8, 6)         True True
# regressor_8/Kernel                                 [ 36   1   1 128]    conv2d_42/Kernel                                   (1, 1, 128, 36)      True True
# regressor_8/Bias                                   [36]                 conv2d_42/Bias                                     (36,)                True True
# regressor_8                                        [ 1 32 32 36]        conv2d_42                                          (1, 32, 32, 36)      True True
# regressor_16/Kernel                                [ 36   1   1 256]    conv2d_43/Kernel                                   (1, 1, 256, 36)      True True
# regressor_16/Bias                                  [36]                 conv2d_43/Bias                                     (36,)                True True
# regressor_16                                       [ 1 16 16 36]        conv2d_43                                          (1, 16, 16, 36)      True True
# regressor_32/Kernel                                [108   1   1 256]    conv2d_44/Kernel                                   (1, 1, 256, 108)     True True
# regressor_32/Bias                                  [108]                conv2d_44/Bias                                     (108,)               True True
# regressor_32                                       [  1   8   8 108]    conv2d_44                                          (1, 8, 8, 108)       True True
# reshape                                            [   1 2048    1]     reshape_3                                          (1, 2048, 1)         False False
# reshape_2                                          [  1 512   1]        reshape_4                                          (1, 512, 1)          False False
# reshape_4                                          [  1 384   1]        reshape_5                                          (1, 384, 1)          False False
# reshape_1                                          [   1 2048   18]     reshape                                            (1, 2048, 18)        False False
# reshape_3                                          [  1 512  18]        reshape_1                                          (1, 512, 18)         False False
# reshape_5                                          [  1 384  18]        reshape_2                                          (1, 384, 18)         False False
# classificators                                     [   1 2944    1]     concatenate_1                                      (1, 2944, 1)         True True
# regressors                                         [   1 2944   18]     concatenate                                        (1, 2944, 18)        True True

# %%
no_direct_match_mapping = {
    "conv2d_42": "regressor_8",
    "conv2d_43": "regressor_16",
    "conv2d_44": "regressor_32",
    "conv2d_45": "classificator_8",
    "conv2d_46": "classificator_16",
    "conv2d_47": "classificator_32",
}

# %%
for n in layer_name_layer_map.keys():
    if "conv2d" not in n: # Only conv2d has weights to transfer. SSD is fully conv
        continue

    layer = layer_name_layer_map[n]
    
    if n in no_direct_match_mapping:
        n = no_direct_match_mapping[n]

    kernel_name = n + '/Kernel'
    bias_name = n + '/Bias'

    assert kernel_name in weights_dict
    assert bias_name in weights_dict

    kernel_weights_buf = weights_dict[kernel_name]
    kernel_weights = np.frombuffer(kernel_weights_buf, dtype=np.float32)
    kernel_weights = kernel_weights.reshape(weights_shape_dict[kernel_name])
    if ("transpose" not in kernel_name):
        kernel_weights = kernel_weights.transpose((1, 2, 3, 0))
    else:
        kernel_weights = kernel_weights.transpose(( 1, 2, 0, 3))

    bias_weights_buf = weights_dict[bias_name]
    bias_weights = np.frombuffer(bias_weights_buf, dtype=np.float32)
    
    # Copy weights over
    print(
        n.ljust(30),
        str(weights_shape_dict[kernel_name]).ljust(20),
        str(kernel_weights.shape).ljust(10),
        str(layer.get_weights()[0].shape).ljust(40),
        str(weights_shape_dict[bias_name]).ljust(10),
        str(bias_weights.shape).ljust(10),
        str(layer.get_weights()[1].shape).ljust(10),
    )

    assert kernel_weights.shape == layer.get_weights()[0].shape
    assert bias_weights.shape == layer.get_weights()[1].shape
    layer.set_weights([kernel_weights, bias_weights])
# Out:
# conv2d                         [32  3  3  3]        (3, 3, 3, 32) (3, 3, 3, 32)                            [32]       (32,)      (32,)
# depthwise_conv2d               [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_1                       [32  1  1 32]        (1, 1, 32, 32) (1, 1, 32, 32)                           [32]       (32,)      (32,)
# depthwise_conv2d_1             [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_2                       [32  1  1 32]        (1, 1, 32, 32) (1, 1, 32, 32)                           [32]       (32,)      (32,)
# depthwise_conv2d_2             [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_3                       [32  1  1 32]        (1, 1, 32, 32) (1, 1, 32, 32)                           [32]       (32,)      (32,)
# depthwise_conv2d_3             [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_4                       [32  1  1 32]        (1, 1, 32, 32) (1, 1, 32, 32)                           [32]       (32,)      (32,)
# depthwise_conv2d_4             [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_5                       [32  1  1 32]        (1, 1, 32, 32) (1, 1, 32, 32)                           [32]       (32,)      (32,)
# depthwise_conv2d_5             [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_6                       [32  1  1 32]        (1, 1, 32, 32) (1, 1, 32, 32)                           [32]       (32,)      (32,)
# depthwise_conv2d_6             [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_7                       [32  1  1 32]        (1, 1, 32, 32) (1, 1, 32, 32)                           [32]       (32,)      (32,)
# depthwise_conv2d_7             [ 1  3  3 32]        (3, 3, 32, 1) (3, 3, 32, 1)                            [32]       (32,)      (32,)
# conv2d_8                       [64  1  1 32]        (1, 1, 32, 64) (1, 1, 32, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_8             [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_9                       [64  1  1 64]        (1, 1, 64, 64) (1, 1, 64, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_9             [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_10                      [64  1  1 64]        (1, 1, 64, 64) (1, 1, 64, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_10            [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_11                      [64  1  1 64]        (1, 1, 64, 64) (1, 1, 64, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_11            [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_12                      [64  1  1 64]        (1, 1, 64, 64) (1, 1, 64, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_12            [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_13                      [64  1  1 64]        (1, 1, 64, 64) (1, 1, 64, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_13            [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_14                      [64  1  1 64]        (1, 1, 64, 64) (1, 1, 64, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_14            [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_15                      [64  1  1 64]        (1, 1, 64, 64) (1, 1, 64, 64)                           [64]       (64,)      (64,)
# depthwise_conv2d_15            [ 1  3  3 64]        (3, 3, 64, 1) (3, 3, 64, 1)                            [64]       (64,)      (64,)
# conv2d_16                      [128   1   1  64]    (1, 1, 64, 128) (1, 1, 64, 128)                          [128]      (128,)     (128,)
# depthwise_conv2d_16            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_17                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# depthwise_conv2d_17            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_18                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# depthwise_conv2d_18            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_19                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# depthwise_conv2d_19            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_20                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# depthwise_conv2d_20            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_21                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# depthwise_conv2d_21            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_22                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# depthwise_conv2d_22            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_23                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# depthwise_conv2d_23            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_24                      [256   1   1 128]    (1, 1, 128, 256) (1, 1, 128, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_24            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_25                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_25            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_26                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_26            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_27                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_27            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_28                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_28            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_29                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_29            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_30                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_30            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_31                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_31            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_32                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_32            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_33                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_33            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_34                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_34            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_35                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_35            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_36                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_36            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_37                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_37            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_38                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_38            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_39                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# conv2d_transpose               [256   2   2 256]    (2, 2, 256, 256) (2, 2, 256, 256)                         [256]      (256,)     (256,)
# depthwise_conv2d_39            [  1   3   3 256]    (3, 3, 256, 1) (3, 3, 256, 1)                           [256]      (256,)     (256,)
# conv2d_40                      [256   1   1 256]    (1, 1, 256, 256) (1, 1, 256, 256)                         [256]      (256,)     (256,)
# conv2d_transpose_1             [128   2   2 256]    (2, 2, 128, 256) (2, 2, 128, 256)                         [128]      (128,)     (128,)
# depthwise_conv2d_40            [  1   3   3 128]    (3, 3, 128, 1) (3, 3, 128, 1)                           [128]      (128,)     (128,)
# conv2d_41                      [128   1   1 128]    (1, 1, 128, 128) (1, 1, 128, 128)                         [128]      (128,)     (128,)
# classificator_8                [  2   1   1 128]    (1, 1, 128, 2) (1, 1, 128, 2)                           [2]        (2,)       (2,)
# classificator_16               [  2   1   1 256]    (1, 1, 256, 2) (1, 1, 256, 2)                           [2]        (2,)       (2,)
# classificator_32               [  6   1   1 256]    (1, 1, 256, 6) (1, 1, 256, 6)                           [6]        (6,)       (6,)
# regressor_8                    [ 36   1   1 128]    (1, 1, 128, 36) (1, 1, 128, 36)                          [36]       (36,)      (36,)
# regressor_16                   [ 36   1   1 256]    (1, 1, 256, 36) (1, 1, 256, 36)                          [36]       (36,)      (36,)
# regressor_32                   [108   1   1 256]    (1, 1, 256, 108) (1, 1, 256, 108)                         [108]      (108,)     (108,)

# %%
tf.saved_model.save(model, "palm_detection_tf_finetuned")
# Out:
# INFO:tensorflow:Assets written to: palm_detection_tf_finetuned\assets

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(1, 256, 256, 3)]   0           []
#
#  conv2d (Conv2D)                (1, 128, 128, 32)    896         ['input_1[0][0]']
#
#  activation (Activation)        (1, 128, 128, 32)    0           ['conv2d[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (1, 128, 128, 32)   320         ['activation[0][0]']
#  v2D)
#
#  conv2d_1 (Conv2D)              (1, 128, 128, 32)    1056        ['depthwise_conv2d[0][0]']
#
#  add (Add)                      (1, 128, 128, 32)    0           ['conv2d_1[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_1 (Activation)      (1, 128, 128, 32)    0           ['add[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (1, 128, 128, 32)   320         ['activation_1[0][0]']
#  onv2D)
#
#  conv2d_2 (Conv2D)              (1, 128, 128, 32)    1056        ['depthwise_conv2d_1[0][0]']
#
#  add_1 (Add)                    (1, 128, 128, 32)    0           ['conv2d_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_2 (Activation)      (1, 128, 128, 32)    0           ['add_1[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (1, 128, 128, 32)   320         ['activation_2[0][0]']
#  onv2D)
#
#  conv2d_3 (Conv2D)              (1, 128, 128, 32)    1056        ['depthwise_conv2d_2[0][0]']
#
#  add_2 (Add)                    (1, 128, 128, 32)    0           ['conv2d_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_3 (Activation)      (1, 128, 128, 32)    0           ['add_2[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (1, 128, 128, 32)   320         ['activation_3[0][0]']
#  onv2D)
#
#  conv2d_4 (Conv2D)              (1, 128, 128, 32)    1056        ['depthwise_conv2d_3[0][0]']
#
#  add_3 (Add)                    (1, 128, 128, 32)    0           ['conv2d_4[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_4 (Activation)      (1, 128, 128, 32)    0           ['add_3[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (1, 128, 128, 32)   320         ['activation_4[0][0]']
#  onv2D)
#
#  conv2d_5 (Conv2D)              (1, 128, 128, 32)    1056        ['depthwise_conv2d_4[0][0]']
#
#  add_4 (Add)                    (1, 128, 128, 32)    0           ['conv2d_5[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (1, 128, 128, 32)    0           ['add_4[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (1, 128, 128, 32)   320         ['activation_5[0][0]']
#  onv2D)
#
#  conv2d_6 (Conv2D)              (1, 128, 128, 32)    1056        ['depthwise_conv2d_5[0][0]']
#
#  add_5 (Add)                    (1, 128, 128, 32)    0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  activation_6 (Activation)      (1, 128, 128, 32)    0           ['add_5[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (1, 128, 128, 32)   320         ['activation_6[0][0]']
#  onv2D)
#
#  conv2d_7 (Conv2D)              (1, 128, 128, 32)    1056        ['depthwise_conv2d_6[0][0]']
#
#  add_6 (Add)                    (1, 128, 128, 32)    0           ['conv2d_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_7 (Activation)      (1, 128, 128, 32)    0           ['add_6[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (1, 64, 64, 32)      0           ['activation_7[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (1, 64, 64, 32)     320         ['activation_7[0][0]']
#  onv2D)
#
#  tf.zeros_like (TFOpLambda)     (1, 64, 64, 32)      0           ['max_pooling2d[0][0]']
#
#  conv2d_8 (Conv2D)              (1, 64, 64, 64)      2112        ['depthwise_conv2d_7[0][0]']
#
#  tf.concat (TFOpLambda)         (1, 64, 64, 64)      0           ['max_pooling2d[0][0]',
#                                                                   'tf.zeros_like[0][0]']
#
#  add_7 (Add)                    (1, 64, 64, 64)      0           ['conv2d_8[0][0]',
#                                                                   'tf.concat[0][0]']
#
#  activation_8 (Activation)      (1, 64, 64, 64)      0           ['add_7[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (1, 64, 64, 64)     640         ['activation_8[0][0]']
#  onv2D)
#
#  conv2d_9 (Conv2D)              (1, 64, 64, 64)      4160        ['depthwise_conv2d_8[0][0]']
#
#  add_8 (Add)                    (1, 64, 64, 64)      0           ['conv2d_9[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_9 (Activation)      (1, 64, 64, 64)      0           ['add_8[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (1, 64, 64, 64)     640         ['activation_9[0][0]']
#  onv2D)
#
#  conv2d_10 (Conv2D)             (1, 64, 64, 64)      4160        ['depthwise_conv2d_9[0][0]']
#
#  add_9 (Add)                    (1, 64, 64, 64)      0           ['conv2d_10[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_10 (Activation)     (1, 64, 64, 64)      0           ['add_9[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (1, 64, 64, 64)     640         ['activation_10[0][0]']
#  Conv2D)
#
#  conv2d_11 (Conv2D)             (1, 64, 64, 64)      4160        ['depthwise_conv2d_10[0][0]']
#
#  add_10 (Add)                   (1, 64, 64, 64)      0           ['conv2d_11[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_11 (Activation)     (1, 64, 64, 64)      0           ['add_10[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (1, 64, 64, 64)     640         ['activation_11[0][0]']
#  Conv2D)
#
#  conv2d_12 (Conv2D)             (1, 64, 64, 64)      4160        ['depthwise_conv2d_11[0][0]']
#
#  add_11 (Add)                   (1, 64, 64, 64)      0           ['conv2d_12[0][0]',
#                                                                   'activation_11[0][0]']
#
#  activation_12 (Activation)     (1, 64, 64, 64)      0           ['add_11[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (1, 64, 64, 64)     640         ['activation_12[0][0]']
#  Conv2D)
#
#  conv2d_13 (Conv2D)             (1, 64, 64, 64)      4160        ['depthwise_conv2d_12[0][0]']
#
#  add_12 (Add)                   (1, 64, 64, 64)      0           ['conv2d_13[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_13 (Activation)     (1, 64, 64, 64)      0           ['add_12[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (1, 64, 64, 64)     640         ['activation_13[0][0]']
#  Conv2D)
#
#  conv2d_14 (Conv2D)             (1, 64, 64, 64)      4160        ['depthwise_conv2d_13[0][0]']
#
#  add_13 (Add)                   (1, 64, 64, 64)      0           ['conv2d_14[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_14 (Activation)     (1, 64, 64, 64)      0           ['add_13[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (1, 64, 64, 64)     640         ['activation_14[0][0]']
#  Conv2D)
#
#  conv2d_15 (Conv2D)             (1, 64, 64, 64)      4160        ['depthwise_conv2d_14[0][0]']
#
#  add_14 (Add)                   (1, 64, 64, 64)      0           ['conv2d_15[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_15 (Activation)     (1, 64, 64, 64)      0           ['add_14[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (1, 32, 32, 64)     0           ['activation_15[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (1, 32, 32, 64)     640         ['activation_15[0][0]']
#  Conv2D)
#
#  tf.zeros_like_1 (TFOpLambda)   (1, 32, 32, 64)      0           ['max_pooling2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (1, 32, 32, 128)     8320        ['depthwise_conv2d_15[0][0]']
#
#  tf.concat_1 (TFOpLambda)       (1, 32, 32, 128)     0           ['max_pooling2d_1[0][0]',
#                                                                   'tf.zeros_like_1[0][0]']
#
#  add_15 (Add)                   (1, 32, 32, 128)     0           ['conv2d_16[0][0]',
#                                                                   'tf.concat_1[0][0]']
#
#  activation_16 (Activation)     (1, 32, 32, 128)     0           ['add_15[0][0]']
#
#  depthwise_conv2d_16 (Depthwise  (1, 32, 32, 128)    1280        ['activation_16[0][0]']
#  Conv2D)
#
#  conv2d_17 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_16[0][0]']
#
#  add_16 (Add)                   (1, 32, 32, 128)     0           ['conv2d_17[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_17 (Activation)     (1, 32, 32, 128)     0           ['add_16[0][0]']
#
#  depthwise_conv2d_17 (Depthwise  (1, 32, 32, 128)    1280        ['activation_17[0][0]']
#  Conv2D)
#
#  conv2d_18 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_17[0][0]']
#
#  add_17 (Add)                   (1, 32, 32, 128)     0           ['conv2d_18[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_18 (Activation)     (1, 32, 32, 128)     0           ['add_17[0][0]']
#
#  depthwise_conv2d_18 (Depthwise  (1, 32, 32, 128)    1280        ['activation_18[0][0]']
#  Conv2D)
#
#  conv2d_19 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_18[0][0]']
#
#  add_18 (Add)                   (1, 32, 32, 128)     0           ['conv2d_19[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_19 (Activation)     (1, 32, 32, 128)     0           ['add_18[0][0]']
#
#  depthwise_conv2d_19 (Depthwise  (1, 32, 32, 128)    1280        ['activation_19[0][0]']
#  Conv2D)
#
#  conv2d_20 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_19[0][0]']
#
#  add_19 (Add)                   (1, 32, 32, 128)     0           ['conv2d_20[0][0]',
#                                                                   'activation_19[0][0]']
#
#  activation_20 (Activation)     (1, 32, 32, 128)     0           ['add_19[0][0]']
#
#  depthwise_conv2d_20 (Depthwise  (1, 32, 32, 128)    1280        ['activation_20[0][0]']
#  Conv2D)
#
#  conv2d_21 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_20[0][0]']
#
#  add_20 (Add)                   (1, 32, 32, 128)     0           ['conv2d_21[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_21 (Activation)     (1, 32, 32, 128)     0           ['add_20[0][0]']
#
#  depthwise_conv2d_21 (Depthwise  (1, 32, 32, 128)    1280        ['activation_21[0][0]']
#  Conv2D)
#
#  conv2d_22 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_21[0][0]']
#
#  add_21 (Add)                   (1, 32, 32, 128)     0           ['conv2d_22[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_22 (Activation)     (1, 32, 32, 128)     0           ['add_21[0][0]']
#
#  depthwise_conv2d_22 (Depthwise  (1, 32, 32, 128)    1280        ['activation_22[0][0]']
#  Conv2D)
#
#  conv2d_23 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_22[0][0]']
#
#  add_22 (Add)                   (1, 32, 32, 128)     0           ['conv2d_23[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_23 (Activation)     (1, 32, 32, 128)     0           ['add_22[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (1, 16, 16, 128)    0           ['activation_23[0][0]']
#
#  depthwise_conv2d_23 (Depthwise  (1, 16, 16, 128)    1280        ['activation_23[0][0]']
#  Conv2D)
#
#  tf.zeros_like_2 (TFOpLambda)   (1, 16, 16, 128)     0           ['max_pooling2d_2[0][0]']
#
#  conv2d_24 (Conv2D)             (1, 16, 16, 256)     33024       ['depthwise_conv2d_23[0][0]']
#
#  tf.concat_2 (TFOpLambda)       (1, 16, 16, 256)     0           ['max_pooling2d_2[0][0]',
#                                                                   'tf.zeros_like_2[0][0]']
#
#  add_23 (Add)                   (1, 16, 16, 256)     0           ['conv2d_24[0][0]',
#                                                                   'tf.concat_2[0][0]']
#
#  activation_24 (Activation)     (1, 16, 16, 256)     0           ['add_23[0][0]']
#
#  depthwise_conv2d_24 (Depthwise  (1, 16, 16, 256)    2560        ['activation_24[0][0]']
#  Conv2D)
#
#  conv2d_25 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_24[0][0]']
#
#  add_24 (Add)                   (1, 16, 16, 256)     0           ['conv2d_25[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_25 (Activation)     (1, 16, 16, 256)     0           ['add_24[0][0]']
#
#  depthwise_conv2d_25 (Depthwise  (1, 16, 16, 256)    2560        ['activation_25[0][0]']
#  Conv2D)
#
#  conv2d_26 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_25[0][0]']
#
#  add_25 (Add)                   (1, 16, 16, 256)     0           ['conv2d_26[0][0]',
#                                                                   'activation_25[0][0]']
#
#  activation_26 (Activation)     (1, 16, 16, 256)     0           ['add_25[0][0]']
#
#  depthwise_conv2d_26 (Depthwise  (1, 16, 16, 256)    2560        ['activation_26[0][0]']
#  Conv2D)
#
#  conv2d_27 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_26[0][0]']
#
#  add_26 (Add)                   (1, 16, 16, 256)     0           ['conv2d_27[0][0]',
#                                                                   'activation_26[0][0]']
#
#  activation_27 (Activation)     (1, 16, 16, 256)     0           ['add_26[0][0]']
#
#  depthwise_conv2d_27 (Depthwise  (1, 16, 16, 256)    2560        ['activation_27[0][0]']
#  Conv2D)
#
#  conv2d_28 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_27[0][0]']
#
#  add_27 (Add)                   (1, 16, 16, 256)     0           ['conv2d_28[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_28 (Activation)     (1, 16, 16, 256)     0           ['add_27[0][0]']
#
#  depthwise_conv2d_28 (Depthwise  (1, 16, 16, 256)    2560        ['activation_28[0][0]']
#  Conv2D)
#
#  conv2d_29 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_28[0][0]']
#
#  add_28 (Add)                   (1, 16, 16, 256)     0           ['conv2d_29[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_29 (Activation)     (1, 16, 16, 256)     0           ['add_28[0][0]']
#
#  depthwise_conv2d_29 (Depthwise  (1, 16, 16, 256)    2560        ['activation_29[0][0]']
#  Conv2D)
#
#  conv2d_30 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_29[0][0]']
#
#  add_29 (Add)                   (1, 16, 16, 256)     0           ['conv2d_30[0][0]',
#                                                                   'activation_29[0][0]']
#
#  activation_30 (Activation)     (1, 16, 16, 256)     0           ['add_29[0][0]']
#
#  depthwise_conv2d_30 (Depthwise  (1, 16, 16, 256)    2560        ['activation_30[0][0]']
#  Conv2D)
#
#  conv2d_31 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_30[0][0]']
#
#  add_30 (Add)                   (1, 16, 16, 256)     0           ['conv2d_31[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_31 (Activation)     (1, 16, 16, 256)     0           ['add_30[0][0]']
#
#  depthwise_conv2d_31 (Depthwise  (1, 8, 8, 256)      2560        ['activation_31[0][0]']
#  Conv2D)
#
#  conv2d_32 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_31[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (1, 8, 8, 256)      0           ['activation_31[0][0]']
#
#  add_31 (Add)                   (1, 8, 8, 256)       0           ['conv2d_32[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  activation_32 (Activation)     (1, 8, 8, 256)       0           ['add_31[0][0]']
#
#  depthwise_conv2d_32 (Depthwise  (1, 8, 8, 256)      2560        ['activation_32[0][0]']
#  Conv2D)
#
#  conv2d_33 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_32[0][0]']
#
#  add_32 (Add)                   (1, 8, 8, 256)       0           ['conv2d_33[0][0]',
#                                                                   'activation_32[0][0]']
#
#  activation_33 (Activation)     (1, 8, 8, 256)       0           ['add_32[0][0]']
#
#  depthwise_conv2d_33 (Depthwise  (1, 8, 8, 256)      2560        ['activation_33[0][0]']
#  Conv2D)
#
#  conv2d_34 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_33[0][0]']
#
#  add_33 (Add)                   (1, 8, 8, 256)       0           ['conv2d_34[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_34 (Activation)     (1, 8, 8, 256)       0           ['add_33[0][0]']
#
#  depthwise_conv2d_34 (Depthwise  (1, 8, 8, 256)      2560        ['activation_34[0][0]']
#  Conv2D)
#
#  conv2d_35 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_34[0][0]']
#
#  add_34 (Add)                   (1, 8, 8, 256)       0           ['conv2d_35[0][0]',
#                                                                   'activation_34[0][0]']
#
#  activation_35 (Activation)     (1, 8, 8, 256)       0           ['add_34[0][0]']
#
#  depthwise_conv2d_35 (Depthwise  (1, 8, 8, 256)      2560        ['activation_35[0][0]']
#  Conv2D)
#
#  conv2d_36 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_35[0][0]']
#
#  add_35 (Add)                   (1, 8, 8, 256)       0           ['conv2d_36[0][0]',
#                                                                   'activation_35[0][0]']
#
#  activation_36 (Activation)     (1, 8, 8, 256)       0           ['add_35[0][0]']
#
#  depthwise_conv2d_36 (Depthwise  (1, 8, 8, 256)      2560        ['activation_36[0][0]']
#  Conv2D)
#
#  conv2d_37 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_36[0][0]']
#
#  add_36 (Add)                   (1, 8, 8, 256)       0           ['conv2d_37[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_37 (Activation)     (1, 8, 8, 256)       0           ['add_36[0][0]']
#
#  depthwise_conv2d_37 (Depthwise  (1, 8, 8, 256)      2560        ['activation_37[0][0]']
#  Conv2D)
#
#  conv2d_38 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_37[0][0]']
#
#  add_37 (Add)                   (1, 8, 8, 256)       0           ['conv2d_38[0][0]',
#                                                                   'activation_37[0][0]']
#
#  activation_38 (Activation)     (1, 8, 8, 256)       0           ['add_37[0][0]']
#
#  depthwise_conv2d_38 (Depthwise  (1, 8, 8, 256)      2560        ['activation_38[0][0]']
#  Conv2D)
#
#  conv2d_39 (Conv2D)             (1, 8, 8, 256)       65792       ['depthwise_conv2d_38[0][0]']
#
#  add_38 (Add)                   (1, 8, 8, 256)       0           ['conv2d_39[0][0]',
#                                                                   'activation_38[0][0]']
#
#  activation_39 (Activation)     (1, 8, 8, 256)       0           ['add_38[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (1, 16, 16, 256)    262400      ['activation_39[0][0]']
#  ose)
#
#  activation_40 (Activation)     (1, 16, 16, 256)     0           ['conv2d_transpose[0][0]']
#
#  add_39 (Add)                   (1, 16, 16, 256)     0           ['activation_40[0][0]',
#                                                                   'activation_31[0][0]']
#
#  depthwise_conv2d_39 (Depthwise  (1, 16, 16, 256)    2560        ['add_39[0][0]']
#  Conv2D)
#
#  conv2d_40 (Conv2D)             (1, 16, 16, 256)     65792       ['depthwise_conv2d_39[0][0]']
#
#  add_40 (Add)                   (1, 16, 16, 256)     0           ['conv2d_40[0][0]',
#                                                                   'add_39[0][0]']
#
#  activation_41 (Activation)     (1, 16, 16, 256)     0           ['add_40[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (1, 32, 32, 128)    131200      ['activation_41[0][0]']
#  spose)
#
#  activation_42 (Activation)     (1, 32, 32, 128)     0           ['conv2d_transpose_1[0][0]']
#
#  add_41 (Add)                   (1, 32, 32, 128)     0           ['activation_42[0][0]',
#                                                                   'activation_23[0][0]']
#
#  depthwise_conv2d_40 (Depthwise  (1, 32, 32, 128)    1280        ['add_41[0][0]']
#  Conv2D)
#
#  conv2d_41 (Conv2D)             (1, 32, 32, 128)     16512       ['depthwise_conv2d_40[0][0]']
#
#  add_42 (Add)                   (1, 32, 32, 128)     0           ['conv2d_41[0][0]',
#                                                                   'add_41[0][0]']
#
#  activation_43 (Activation)     (1, 32, 32, 128)     0           ['add_42[0][0]']
#
#  conv2d_45 (Conv2D)             (1, 32, 32, 2)       258         ['activation_43[0][0]']
#
#  conv2d_46 (Conv2D)             (1, 16, 16, 2)       514         ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (1, 8, 8, 6)         1542        ['activation_39[0][0]']
#
#  conv2d_42 (Conv2D)             (1, 32, 32, 36)      4644        ['activation_43[0][0]']
#
#  conv2d_43 (Conv2D)             (1, 16, 16, 36)      9252        ['activation_41[0][0]']
#
#  conv2d_44 (Conv2D)             (1, 8, 8, 108)       27756       ['activation_39[0][0]']
#
#  reshape_3 (Reshape)            (1, 2048, 1)         0           ['conv2d_45[0][0]']
#
#  reshape_4 (Reshape)            (1, 512, 1)          0           ['conv2d_46[0][0]']
#
#  reshape_5 (Reshape)            (1, 384, 1)          0           ['conv2d_47[0][0]']
#
#  reshape (Reshape)              (1, 2048, 18)        0           ['conv2d_42[0][0]']
#
#  reshape_1 (Reshape)            (1, 512, 18)         0           ['conv2d_43[0][0]']
#
#  reshape_2 (Reshape)            (1, 384, 18)         0           ['conv2d_44[0][0]']
#
#  concatenate_1 (Concatenate)    (1, 2944, 1)         0           ['reshape_3[0][0]',
#                                                                   'reshape_4[0][0]',
#                                                                   'reshape_5[0][0]']
#
#  concatenate (Concatenate)      (1, 2944, 18)        0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]',
#                                                                   'reshape_2[0][0]']
#
# ==================================================================================================
# Total params: 1,763,358
# Trainable params: 1,763,358
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
converter = tf.lite.TFLiteConverter.from_saved_model("palm_detection_tf_finetuned", signature_keys=None)

# converter.experimental_new_converter = True
# converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

# Save the model.
with open('palm_detection_tf_finetuned.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
TFLITE_MODEL_PATH = 'palm_detection_tf_finetuned.tflite'
release_model = tf.lite.Interpreter(model_path=TFLITE_MODEL_PATH)

# %%
release_model.get_output_details()
# Out:
# [{'name': 'StatefulPartitionedCall:0',
#   'index': 300,
#   'shape': array([   1, 2944,   18]),
#   'shape_signature': array([   1, 2944,   18]),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}},
#  {'name': 'StatefulPartitionedCall:1',
#   'index': 303,
#   'shape': array([   1, 2944,    1]),
#   'shape_signature': array([   1, 2944,    1]),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]

# %% [markdown]
# # Below Not Used

# %%
layer_name_list = []
layer_shape_list = []
for layer in model.layers:
    if "conv2d" in layer.name:
        layer_name_list.append(layer.name + '/Kernel')
        layer_name_list.append(layer.name + '/Bias')
        layer_name_list.append(layer.name)
        layer_shape_list.append(layer.get_weights()[0].shape)
        layer_shape_list.append(layer.get_weights()[1].shape)
        layer_shape_list.append(layer.output_shape)
    else:
        layer_name_list.append(layer.name)
        layer_shape_list.append(layer.output_shape)

print(len(layer_name_list))
print(len(release_model.get_tensor_details()))

for i in range(len(layer_name_list)):
    tensor = subgraph.Tensors(i) 
    layer_name = tensor.Name()
    buffer_idx = tensor.Buffer()
    buffer = rel_model.Buffers(buffer_idx)
    if "conv2d" in layer_name:
        weights = buffer.DataAsNumpy().reshape(tensor.ShapeAsNumpy())
    else:
        weights = np.zeros(1)

    print(layer_name.ljust(30), str(weights.shape).ljust(20), layer_name_list[i].ljust(30), layer_shape_list[i])
# Out:
# 380
# 419
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20040/3729710803.py in <module>
#      21     buffer_idx = tensor.Buffer()
#      22     buffer = rel_model.Buffers(buffer_idx)
# ---> 23     if "conv2d" in layer_name:
#      24         weights = buffer.DataAsNumpy().reshape(tensor.ShapeAsNumpy())
#      25     else:
#
# TypeError: a bytes-like object is required, not 'str'

# %%
for layer in release_model.get_tensor_details():
      print("\nLayer Name: {}".format(layer['name']))
      print("\tIndex: {}".format(layer['index']))
      print("\n\tShape: {}".format(layer['shape']))
      print("\tTensor: {}".format(release_model.tensor(layer['index'])))
      print("\tTensor Type: {}".format(release_model.get_tensor(layer['index']).dtype))
      print("\tQuantisation Parameters")
      print("\t\tScales: {}".format(layer['quantization_parameters']['scales'].shape))
      print("\t\tScales Type: {}".format(layer['quantization_parameters']['scales'].dtype))
      print("\t\tZero Points: {}".format(layer['quantization_parameters']['zero_points']))
      print("\t\tQuantized Dimension: {}".format(layer['quantization_parameters']['quantized_dimension']))
# Out:
# Layer Name: Const
# 	Index: 0
#
# 	Shape: [4 2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: Const_1
# 	Index: 1
#
# 	Shape: [4 2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49940>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: Const_2
# 	Index: 2
#
# 	Shape: [4 2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: add_39/add
# 	Index: 3
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: add_41/add
# 	Index: 4
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22161820>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_16/BiasAdd
# 	Index: 5
#
# 	Shape: [ 1 16 16  2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2219D4C0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_16/Conv2D_bias
# 	Index: 6
#
# 	Shape: [2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_16/kernel
# 	Index: 7
#
# 	Shape: [  2   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_32/BiasAdd
# 	Index: 8
#
# 	Shape: [1 8 8 6]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_32/Conv2D_bias
# 	Index: 9
#
# 	Shape: [6]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_32/kernel
# 	Index: 10
#
# 	Shape: [  6   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_8/BiasAdd
# 	Index: 11
#
# 	Shape: [ 1 32 32  2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_8/Conv2D_bias
# 	Index: 12
#
# 	Shape: [2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificator_8/kernel
# 	Index: 13
#
# 	Shape: [  2   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2217A4C0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: classificators/concat
# 	Index: 14
#
# 	Shape: [   1 2944    1]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2217AE50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d/Conv2D_bias
# 	Index: 15
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d/kernel
# 	Index: 16
#
# 	Shape: [32  3  3  3]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_1/BiasAdd
# 	Index: 17
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_1/Conv2D_bias
# 	Index: 18
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22188670>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_1/kernel
# 	Index: 19
#
# 	Shape: [32  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_10/BiasAdd
# 	Index: 20
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_10/Conv2D_bias
# 	Index: 21
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_10/kernel
# 	Index: 22
#
# 	Shape: [64  1  1 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_11/BiasAdd
# 	Index: 23
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_11/Conv2D_bias
# 	Index: 24
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_11/kernel
# 	Index: 25
#
# 	Shape: [64  1  1 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_12/BiasAdd
# 	Index: 26
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_12/Conv2D_bias
# 	Index: 27
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_12/kernel
# 	Index: 28
#
# 	Shape: [64  1  1 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_13/BiasAdd
# 	Index: 29
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_13/Conv2D_bias
# 	Index: 30
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_13/kernel
# 	Index: 31
#
# 	Shape: [64  1  1 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_14/BiasAdd
# 	Index: 32
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_14/Conv2D_bias
# 	Index: 33
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_14/kernel
# 	Index: 34
#
# 	Shape: [64  1  1 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_15/BiasAdd
# 	Index: 35
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_15/Conv2D_bias
# 	Index: 36
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_15/kernel
# 	Index: 37
#
# 	Shape: [64  1  1 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_16/BiasAdd
# 	Index: 38
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_16/Conv2D_bias
# 	Index: 39
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_16/kernel
# 	Index: 40
#
# 	Shape: [128   1   1  64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_17/BiasAdd
# 	Index: 41
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_17/Conv2D_bias
# 	Index: 42
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_17/kernel
# 	Index: 43
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2216E670>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_18/BiasAdd
# 	Index: 44
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2216E3A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_18/Conv2D_bias
# 	Index: 45
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_18/kernel
# 	Index: 46
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_19/BiasAdd
# 	Index: 47
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22178B80>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_19/Conv2D_bias
# 	Index: 48
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22167700>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_19/kernel
# 	Index: 49
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22167E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_2/BiasAdd
# 	Index: 50
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22160DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_2/Conv2D_bias
# 	Index: 51
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49940>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_2/kernel
# 	Index: 52
#
# 	Shape: [32  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2218A8B0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_20/BiasAdd
# 	Index: 53
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22160D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_20/Conv2D_bias
# 	Index: 54
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22160280>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_20/kernel
# 	Index: 55
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_21/BiasAdd
# 	Index: 56
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2218AA60>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_21/Conv2D_bias
# 	Index: 57
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_21/kernel
# 	Index: 58
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_22/BiasAdd
# 	Index: 59
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_22/Conv2D_bias
# 	Index: 60
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_22/kernel
# 	Index: 61
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_23/BiasAdd
# 	Index: 62
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_23/Conv2D_bias
# 	Index: 63
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_23/kernel
# 	Index: 64
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_24/BiasAdd
# 	Index: 65
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_24/Conv2D_bias
# 	Index: 66
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_24/kernel
# 	Index: 67
#
# 	Shape: [256   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_25/BiasAdd
# 	Index: 68
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_25/Conv2D_bias
# 	Index: 69
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_25/kernel
# 	Index: 70
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_26/BiasAdd
# 	Index: 71
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_26/Conv2D_bias
# 	Index: 72
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_26/kernel
# 	Index: 73
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_27/BiasAdd
# 	Index: 74
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_27/Conv2D_bias
# 	Index: 75
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_27/kernel
# 	Index: 76
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49A60>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_28/BiasAdd
# 	Index: 77
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_28/Conv2D_bias
# 	Index: 78
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_28/kernel
# 	Index: 79
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_29/BiasAdd
# 	Index: 80
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_29/Conv2D_bias
# 	Index: 81
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_29/kernel
# 	Index: 82
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_3/BiasAdd
# 	Index: 83
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_3/Conv2D_bias
# 	Index: 84
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_3/kernel
# 	Index: 85
#
# 	Shape: [32  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC221618B0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_30/BiasAdd
# 	Index: 86
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC22161E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_30/Conv2D_bias
# 	Index: 87
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_30/kernel
# 	Index: 88
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_31/BiasAdd
# 	Index: 89
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_31/Conv2D_bias
# 	Index: 90
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_31/kernel
# 	Index: 91
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_32/BiasAdd
# 	Index: 92
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_32/Conv2D_bias
# 	Index: 93
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_32/kernel
# 	Index: 94
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_33/BiasAdd
# 	Index: 95
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_33/Conv2D_bias
# 	Index: 96
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_33/kernel
# 	Index: 97
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_34/BiasAdd
# 	Index: 98
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_34/Conv2D_bias
# 	Index: 99
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_34/kernel
# 	Index: 100
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_35/BiasAdd
# 	Index: 101
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_35/Conv2D_bias
# 	Index: 102
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_35/kernel
# 	Index: 103
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_36/BiasAdd
# 	Index: 104
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_36/Conv2D_bias
# 	Index: 105
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_36/kernel
# 	Index: 106
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_37/BiasAdd
# 	Index: 107
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_37/Conv2D_bias
# 	Index: 108
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_37/kernel
# 	Index: 109
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_38/BiasAdd
# 	Index: 110
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_38/Conv2D_bias
# 	Index: 111
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_38/kernel
# 	Index: 112
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_39/BiasAdd
# 	Index: 113
#
# 	Shape: [  1   8   8 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49A60>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_39/Conv2D_bias
# 	Index: 114
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_39/kernel
# 	Index: 115
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_4/BiasAdd
# 	Index: 116
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_4/Conv2D_bias
# 	Index: 117
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_4/kernel
# 	Index: 118
#
# 	Shape: [32  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_40/BiasAdd
# 	Index: 119
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_40/Conv2D_bias
# 	Index: 120
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_40/kernel
# 	Index: 121
#
# 	Shape: [256   1   1 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_41/BiasAdd
# 	Index: 122
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_41/Conv2D_bias
# 	Index: 123
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_41/kernel
# 	Index: 124
#
# 	Shape: [128   1   1 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_5/BiasAdd
# 	Index: 125
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_5/Conv2D_bias
# 	Index: 126
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_5/kernel
# 	Index: 127
#
# 	Shape: [32  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_6/BiasAdd
# 	Index: 128
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_6/Conv2D_bias
# 	Index: 129
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_6/kernel
# 	Index: 130
#
# 	Shape: [32  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49A60>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_7/BiasAdd
# 	Index: 131
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_7/Conv2D_bias
# 	Index: 132
#
# 	Shape: [32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_7/kernel
# 	Index: 133
#
# 	Shape: [32  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_8/BiasAdd
# 	Index: 134
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_8/Conv2D_bias
# 	Index: 135
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_8/kernel
# 	Index: 136
#
# 	Shape: [64  1  1 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_9/BiasAdd
# 	Index: 137
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_9/Conv2D_bias
# 	Index: 138
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2216E820>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_9/kernel
# 	Index: 139
#
# 	Shape: [64  1  1 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose/bias
# 	Index: 140
#
# 	Shape: [256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose/conv2d_transpose
# 	Index: 141
#
# 	Shape: [  1  16  16 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose/conv2d_transpose/ReadVariableOp_transposed
# 	Index: 142
#
# 	Shape: [256   2   2 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose/stack
# 	Index: 143
#
# 	Shape: [4]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose_1/bias
# 	Index: 144
#
# 	Shape: [128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose_1/conv2d_transpose
# 	Index: 145
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose_1/conv2d_transpose/ReadVariableOp_transposed
# 	Index: 146
#
# 	Shape: [128   2   2 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: conv2d_transpose_1/stack
# 	Index: 147
#
# 	Shape: [4]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d/BiasAdd
# 	Index: 148
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d/depthwise_kernel
# 	Index: 149
#
# 	Shape: [ 1  3  3 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_1/BiasAdd
# 	Index: 150
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_1/depthwise_kernel
# 	Index: 151
#
# 	Shape: [ 1  3  3 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_10/BiasAdd
# 	Index: 152
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_10/depthwise_kernel
# 	Index: 153
#
# 	Shape: [ 1  3  3 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_11/BiasAdd
# 	Index: 154
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_11/depthwise_kernel
# 	Index: 155
#
# 	Shape: [ 1  3  3 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_12/BiasAdd
# 	Index: 156
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_12/depthwise_kernel
# 	Index: 157
#
# 	Shape: [ 1  3  3 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_13/BiasAdd
# 	Index: 158
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_13/depthwise_kernel
# 	Index: 159
#
# 	Shape: [ 1  3  3 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_14/BiasAdd
# 	Index: 160
#
# 	Shape: [ 1 64 64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_14/depthwise_kernel
# 	Index: 161
#
# 	Shape: [ 1  3  3 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2218E820>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_15/BiasAdd
# 	Index: 162
#
# 	Shape: [ 1 32 32 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC221854C0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_15/depthwise_bias
# 	Index: 163
#
# 	Shape: [64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49AF0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_15/depthwise_kernel
# 	Index: 164
#
# 	Shape: [ 1  3  3 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_16/BiasAdd
# 	Index: 165
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_16/depthwise_kernel
# 	Index: 166
#
# 	Shape: [  1   3   3 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC221853A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_17/BiasAdd
# 	Index: 167
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_17/depthwise_kernel
# 	Index: 168
#
# 	Shape: [  1   3   3 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_18/BiasAdd
# 	Index: 169
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_18/depthwise_kernel
# 	Index: 170
#
# 	Shape: [  1   3   3 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_19/BiasAdd
# 	Index: 171
#
# 	Shape: [  1  32  32 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_19/depthwise_kernel
# 	Index: 172
#
# 	Shape: [  1   3   3 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_2/BiasAdd
# 	Index: 173
#
# 	Shape: [  1 128 128  32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: depthwise_conv2d_2/depthwise_kernel
# 	Index: 174
#
# 	Shape: [ 1  3  3 32]
# ...
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_1/Reshape
# 	Index: 298
#
# 	Shape: [  1 512   1]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_1/Reshape/shape
# 	Index: 299
#
# 	Shape: [3]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28EE0>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_2/Reshape
# 	Index: 300
#
# 	Shape: [  1 384   1]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_2/Reshape/shape
# 	Index: 301
#
# 	Shape: [3]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_3/Reshape
# 	Index: 302
#
# 	Shape: [   1 2048   18]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_3/Reshape/shape
# 	Index: 303
#
# 	Shape: [3]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_4/Reshape
# 	Index: 304
#
# 	Shape: [  1 512  18]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_4/Reshape/shape
# 	Index: 305
#
# 	Shape: [3]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_5/Reshape
# 	Index: 306
#
# 	Shape: [  1 384  18]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name: reshape_5/Reshape/shape
# 	Index: 307
#
# 	Shape: [3]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: int32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 308
#
# 	Shape: [27 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 309
#
# 	Shape: [32 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 310
#
# 	Shape: [32 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 311
#
# 	Shape: [32 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 312
#
# 	Shape: [32 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 313
#
# 	Shape: [32 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 314
#
# 	Shape: [32 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 315
#
# 	Shape: [32 32]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 316
#
# 	Shape: [32 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 317
#
# 	Shape: [64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 318
#
# 	Shape: [64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 319
#
# 	Shape: [64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 320
#
# 	Shape: [64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 321
#
# 	Shape: [64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 322
#
# 	Shape: [64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 323
#
# 	Shape: [64 64]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49790>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 324
#
# 	Shape: [ 64 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 325
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 326
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28CA0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 327
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 328
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49940>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 329
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 330
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49A60>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 331
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 332
#
# 	Shape: [128 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49F70>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 333
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 334
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 335
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2219C670>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 336
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 337
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 338
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 339
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 340
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 341
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 342
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 343
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 344
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 345
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 346
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 347
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28DC0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 348
#
# 	Shape: [  64 1024]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D4310>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 349
#
# 	Shape: [  2   2 256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 350
#
# 	Shape: [256 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 351
#
# 	Shape: [256 512]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2217D4C0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 352
#
# 	Shape: [  2   2 128 256]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49940>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 353
#
# 	Shape: [128 128]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC14F965E0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 354
#
# 	Shape: [128   2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49940>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 355
#
# 	Shape: [256   2]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC211D43A0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 356
#
# 	Shape: [256   6]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC2217D430>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 357
#
# 	Shape: [128  36]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A49EE0>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 358
#
# 	Shape: [256  36]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28D30>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0
#
# Layer Name:
# 	Index: 359
#
# 	Shape: [256 108]
# 	Tensor: <function Interpreter.tensor.<locals>.<lambda> at 0x000001EC21A28E50>
# 	Tensor Type: float32
# 	Quantisation Parameters
# 		Scales: (0,)
# 		Scales Type: float32
# 		Zero Points: []
# 		Quantized Dimension: 0

# %%
model.layers[-1].output_shape
# Out:
# [(None, None, 19)]

# %% [markdown]
# ### Test Prediction

# %%
x = np.float32(np.random.random((8, 256, 256, 3)))
prediction = model(x)
print("model ouputs:\nshape of output1(classification): %s\nshape of output2(regression): %s" % (prediction[:,:,0].shape, prediction[:,:,1:].shape))
# Out:
# model ouputs:
# shape of output1(classification): (8, 2944)
# shape of output2(regression): (8, 2944, 18)

# %% [markdown]
# ## Generate Anchors

# %% [markdown]
# **Anchor Setting**
# - num_layers: 5
# - min_scale: 0.1171875
# - max_scale: 0.75
# - input_size_height: 256
# - input_size_width: 256
# - anchor_offset_x: 0.5
# - anchor_offset_y: 0.5
# - strides: (8, 16, 32, 32, 32)
# - aspect_ratios: 1.0
# - fixed_anchor_size: true

# %%
release_anchors_path = os.path.join("original_models", "anchors.csv")
release_anchors = pd.read_csv(release_anchors_path, names=[0,1,2,3])

# %%
anchor_config = AnchorsConfig()
anchor_config.fixed_anchor_size = True
anchor_generator = AnchorsGenerator(anchor_config)
anchors = anchor_generator.generate()
anchors = pd.DataFrame([[anchor.x_center,anchor.y_center, int(anchor.w), int(anchor.h)] for anchor in anchors])

# %% [markdown]
# ### Generate Anchors and Check If It Is Identical to the Mediapipe Release One

# %%
release_anchors.equals(anchors)
# Out:
# True

# %%
release_anchors.head(5)
# Out:
#           0         1  2  3
# 0  0.015625  0.015625  1  1
# 1  0.015625  0.015625  1  1
# 2  0.046875  0.015625  1  1
# 3  0.046875  0.015625  1  1
# 4  0.078125  0.015625  1  1

# %%
anchors.head(5)
# Out:
#           0         1  2  3
# 0  0.015625  0.015625  1  1
# 1  0.015625  0.015625  1  1
# 2  0.046875  0.015625  1  1
# 3  0.046875  0.015625  1  1
# 4  0.078125  0.015625  1  1

# %% [markdown]
# ### Visualize Anchors

# %%
anchor_config = AnchorsConfig(aspect_ratios=[1, 0.5, 2], fixed_anchor_size=False)
anchor_generator = AnchorsGenerator(anchor_config)
anchors = anchor_generator.generate()

anchors = np.array([[anchor.x_center,anchor.y_center, anchor.w, anchor.h] for anchor in anchors])*256
anchors = anchors.astype("int")
# pd.DataFrame(anchors)

# %%
input_image = np.ones((1,256,256,3))*255

# %%
x = 0
padding = 0
color = ['limegreen', 'gray', 'gray', 'gray']
width = [5, 3, 3, 3]
style = ['-', '--', '--', '--']
alpha = [1, 0.5, 0.5, 0.5]
feature_map = {0:8, 4:16, 8:32, 12:32, 16:32}
c1, c2, c3, c4 = pd.DataFrame(anchors)[2].unique()[x:x+4]
condition = (
(pd.DataFrame(anchors)[2] == c1) | \
(pd.DataFrame(anchors)[2] == c2) | \
(pd.DataFrame(anchors)[2] == c3) | \
(pd.DataFrame(anchors)[2] == c4) |\
(pd.DataFrame(anchors)[3] == c1) | \
(pd.DataFrame(anchors)[3] == c2) | \
(pd.DataFrame(anchors)[3] == c3) | \
(pd.DataFrame(anchors)[3] == c4))
show_anchors = np.array(pd.DataFrame(anchors)[condition])


plt.figure(figsize=(10, 10))
plt.title("Anchors on Feature Map %sx%s "% (256//feature_map[x], 256//feature_map[x]))
result_image = np.pad(input_image.copy()[0], ((padding, padding), (padding, padding), (0, 0)), mode='constant')
for show in range(3):
    random_int = np.random.randint(len(show_anchors)//4)*4
    for i, bbox in enumerate(show_anchors[random_int:random_int+4]):
        cx, cy, w, h = bbox
        cx += padding
        cy += padding
        x1, y1, x2, y2 = (cx-w//2, cy-h//2, cx+w//2, cy+h//2)
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1,
                                 linewidth=width[i], 
                                 edgecolor=color[i],
                                 linestyle=style[i],
                                 alpha=alpha[i],
                                 facecolor="none")
        plt.gca().add_patch(rect)
        plt.scatter(cx, cy, color='gold', s=100)

rect = patches.Rectangle((padding, padding), 
                         result_image.shape[1], 
                         result_image.shape[0],
                         linewidth=0,
                         edgecolor=color[i], 
                         linestyle=style[i], 
                         facecolor="none")
plt.gca().add_patch(rect)
plt.xticks(np.arange(padding, 257+padding, feature_map[x]))
plt.yticks(np.arange(padding, 257+padding, feature_map[x]))
plt.grid(linestyle='--', linewidth=2, c='grey', alpha=0.1)
plt.imshow(result_image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Match and Encode Ground Truth Boxes and Anchors

# %% [markdown]
# ### The Jaccard Index ( Intersection Over Union )
#
# For bounding boxes `boxA` and `boxB` with area `areaA` and `areaB`, if their `IOU > 0.5` then positive, if thier `IOU < 0.3` then negative
#
# $IOU = \frac{areaA \cap areaB}{areaA \cup areaB} = \frac{areaA \cap areaB}{areaA + areaB - areaA \cap areaB}$

# %% [markdown]
# Anchors for BlazePalm

# %%
anchor_config = AnchorsConfig(fixed_anchor_size=False)
anchor_generator = AnchorsGenerator(anchor_config)
anchors = anchor_generator.generate()
anchors_normalized = np.array([[anchor.x_center,anchor.y_center, anchor.w, anchor.h] for anchor in anchors])

# %% [markdown]
# Create a Fake Data for one image

# %%
ground_truth_box = np.array([129.64256-60.13495/2, 153.4913-60.13495/2, 129.64256+60.13495/2, 153.4913+60.13495/2, 136.83605957, 177.14094543, 118.33981323, 127.28881073, 130.82832336, 126.52574158, 142.27386475, 131.28793335, 152.84526062, 137.67770386, 119.28163147, 173.47927856, 105.67642212, 152.75184631]).reshape(1, -1)
ground_truth_boxes = np.concatenate([ground_truth_box, ground_truth_box-64])

# %%
def area(boxes):
    return (boxes[:, 2] - boxes[:, 0]) * (boxes[:, 3] - boxes[:, 1])

def intersection(boxes1, boxes2):
    [y_min1, x_min1, y_max1, x_max1] = np.split(boxes1, 4, axis=1)
    [y_min2, x_min2, y_max2, x_max2] = np.split(boxes2, 4, axis=1)
    all_pairs_min_ymax = np.minimum(y_max1, np.transpose(y_max2))
    all_pairs_max_ymin = np.maximum(y_min1, np.transpose(y_min2))
    intersect_heights = np.maximum(np.zeros(all_pairs_max_ymin.shape), all_pairs_min_ymax - all_pairs_max_ymin)
    all_pairs_min_xmax = np.minimum(x_max1, np.transpose(x_max2))
    all_pairs_max_xmin = np.maximum(x_min1, np.transpose(x_min2))
    intersect_widths = np.maximum(np.zeros(all_pairs_max_xmin.shape), all_pairs_min_xmax - all_pairs_max_xmin)
    return intersect_heights * intersect_widths


def iou(boxes1, boxes2):
    """
    boxes1 and boxes2 should be in the same scale and corner format
    """
    intersect = intersection(boxes1, boxes2)
    area1 = area(boxes1)
    area2 = area(boxes2)
    union = np.expand_dims(area1, axis=1) + np.expand_dims(area2, axis=0) - intersect
    return intersect / union

def center_to_corner(center_boxes):
    """
    (cx, cy, w, h) to (y1, x1, y2, x2)
    """
    corner_boxes = np.zeros(center_boxes.shape)
    corner_boxes[:,:2] = center_boxes[:,:2] - center_boxes[:,2:] / 2
    corner_boxes[:,2:] = corner_boxes[:,:2] + center_boxes[:,2:]
    return corner_boxes

def corner_to_center(corner_boxes):
    """
    (x1, y1, x2, y2) to (cx, cy, w, h)
    """
    center_boxes = np.zeros(corner_boxes.shape)
    center_boxes[:,:2] = (corner_boxes[:,:2] + corner_boxes[:,2:]) / 2
    center_boxes[:,2:] = corner_boxes[:,2:] - corner_boxes[:,:2]
    return center_boxes

def match(annotation, anchors, match_threshold=0.5):
    """Match each prior box with the ground truth box of the highest jaccard
    overlap, encode the bounding boxes, then return the matched indices
    corresponding to both confidence and location preds.
    Args:
        match_threshold: (float) The overlap threshold used when mathing boxes. default=0.5
        annotation: (list) Ground truth labels and ground truth boxes, Shape: [(num_obj, 1), (num_obj, num_coordinate)].
        anchors: (np.array) Anchor boxes Shape: [n_priors,4].
        loc_truth: (tensor) Tensor to be filled w/ endcoded location targets.
        conf_truth: (tensor) Tensor to be filled w/ matched indices for conf preds.
        batch_id: (int) current batch index
    Return:
        The matched indices corresponding to 1)location and 2)confidence preds.
    """
    # jaccard index
    ious = iou(annotation[1][:, :4], center_to_corner(anchors))
    best_prior_overlap, best_prior_idx = np.max(ious, 1), np.argmax(ious, 1)
    # [1,num_priors] best ground truth for each prior
    best_truth_overlap, best_truth_idx = np.max(ious, 0), np.argmax(ious, 0)
    best_truth_idx.squeeze()
    best_truth_overlap.squeeze()
    best_prior_idx.squeeze()
    best_prior_overlap.squeeze()
    best_truth_overlap[best_prior_idx] = 2
    for j in range(len(best_prior_idx)):
        best_truth_idx[best_prior_idx[j]] = j
    matches = annotation[1][best_truth_idx]
    
    # Shape: [num_priors]    
    conf = annotation[0][best_truth_idx]         
    # label as background
    conf[best_truth_overlap < match_threshold] = 0  
    loc = encode(matches, anchors)
    
    # [num_priors,4] encoded offsets to learn
    # loc_truth[batch_id] = encoded_loc
    # [num_priors] top class label for each prior
    # conf_truth[batch_id] = conf
    return conf, loc

def encode(matches, anchors):
    """Encode the variances from the priorbox layers into the ground truth boxes
    we have matched (based on jaccard overlap) with the prior boxes.
    Args:
        matches: (tensor) Coords of ground truth for each prior in point-form Shape: [num_priors, 18].
        anchors: (tensor) Prior boxes in center-offset form Shape: [num_priors, 18].
    Return:
        encoded location (tensor), Shape: [num_priors, 18]
    """

    # dist b/t match center and prior's center
    # (x_min, y_min, x_max, y_max) to (center)
    g_cxcy = corner_to_center(matches[:, :4])[:,:2] - anchors[:, :2]   
    g_wh = (matches[:, 2:4] - matches[:, :2])
    g_kp = matches[:, 4:].reshape(-1, 7, 2) - anchors[:, :2].reshape(-1, 1, 2)    

    return np.concatenate([g_cxcy, g_wh, g_kp.reshape(-1, 14)], 1)  # [num_priors, 18]

# %%
num_anchors = 2944
num_coordinates = 18
num_key_points = 7
num_classes = 1
positive_threshold = 0.5
negative_threshold = 0.5

# %%
ground_truth_labels = np.array([[1], [1]])
annotation = [ground_truth_labels, ground_truth_boxes/256]

# %%
conf, loc = match(annotation, anchors_normalized, match_threshold=0.5)

# %%
color = ['limegreen', 'r']
width = [3, 3]
style = ['-', '--']
alpha = [1, 0.2]


plt.figure(figsize=(7, 7))
plt.title("Match Anchors")
result_image = input_image.copy()[0]
for i, bbox in enumerate(anchors_normalized[np.where(conf != 0)[0]]*256):
    cx, cy, w, h = bbox
    x1, y1, x2, y2 = (cx-w//2, cy-h//2, cx+w//2, cy+h//2)    
    if i == 0:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[1], ec=color[1], ls=style[1], alpha=alpha[1], facecolor="none", label='Matched Anchors')
    else:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[1], ec=color[1], ls=style[1], alpha=alpha[1], facecolor="none")
    plt.gca().add_patch(rect)
    plt.scatter(cx, cy, color=color[1], s=10)

for i in range(len(annotation[1])):
    x1, y1, x2, y2 = annotation[1][:,:4][i]*256
    if i == 0:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[0], ec=color[0], ls=style[0], alpha=alpha[0], facecolor="none", label='Ground Truth')
    else:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[0], ec=color[0], ls=style[0], alpha=alpha[0], facecolor="none")
    plt.gca().add_patch(rect)
    plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[0], s=87)

plt.xticks(np.arange(0, 257, 32))
plt.yticks(np.arange(0, 257, 32))
plt.grid(linestyle='--', linewidth=2, c='k', alpha=0.2)
plt.legend()
plt.imshow(result_image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Loss Function and Hard Negative Mining

# %% [markdown]
# **Loss Function**
#
# There are 2 parts in loss, classification loss and localication loss
#
# $L_{total} = L_{cls} + \alpha L_{loc}$: $\alpha=1$ by default
#
# $L_{cls}$: could be softmax, focal loss or etc.
#
# $L_{loc}$: smooth L1 loss, compute with only positive samples
#
# **Hard Negative Mining**
#
# Positive samples is relatively much less than negatives samples.
#
# In order to handle the data embalanced problem, choose only negative samples with lowest confidence score.
#
# The ratio `positive samples:negative samples=1:3` is recommended

# %% [markdown]
# Set `y_true` and `y_pred`

# %%
x = np.float32(np.random.random((10, 256, 256, 3)))
y_pred = model(x)

# %%
y_true_batch = np.zeros((10, num_anchors, num_classes+num_coordinates))
for i in range(10):
    conf, loc = match(annotation, anchors_normalized, match_threshold=0.5)
    y_true_batch[i] = np.concatenate([conf, loc * 256], axis=-1)

# %%
def binary_focal_loss_fixed(y_true, y_pred):
    """
    :param y_true: A tensor of the same shape as `y_pred`
    :param y_pred:  A tensor resulting from a sigmoid
    :return: Output tensor.
    """
    gamma=2.
    alpha=.25
    y_true = tf.cast(y_true, tf.float32)
    # Define epsilon so that the back-propagation will not result in NaN for 0 divisor case
    epsilon = tf.keras.backend.epsilon()
    # Add the epsilon to prediction value
    # y_pred = y_pred + epsilon
    # Clip the prediciton value
    y_pred = tf.keras.backend.clip(y_pred, epsilon, 1.0 - epsilon)
    # Calculate p_t
    p_t = tf.where(tf.keras.backend.equal(y_true, 1), y_pred, 1 - y_pred)
    # Calculate alpha_t
    alpha_factor = tf.keras.backend.ones_like(y_true) * alpha
    alpha_t = tf.where(tf.keras.backend.equal(y_true, 1), alpha_factor, 1 - alpha_factor)
    # Calculate cross entropy
    cross_entropy = -tf.math.log(p_t)
    weight = alpha_t * tf.math.pow((1 - p_t), gamma)
    # Calculate focal loss
    loss = weight * cross_entropy
    # Sum the losses in mini_batch
#     loss = tf.keras.backend.mean(tf.keras.backend.sum(loss, axis=1))
    return loss

def smooth_L1_loss(y_true, y_pred):
    '''
    Compute smooth L1 loss, see references.
    Arguments:
        y_true (nD tensor): A TensorFlow tensor of any shape containing the ground truth data.
            In this context, the expected tensor has shape `(batch_size, #boxes, 4)` and
            contains the ground truth bounding box coordinates, where the last dimension
            contains `(xmin, xmax, ymin, ymax)`.
        y_pred (nD tensor): A TensorFlow tensor of identical structure to `y_true` containing
            the predicted data, in this context the predicted bounding box coordinates.
    Returns:
        The smooth L1 loss, a nD-1 Tensorflow tensor. In this context a 2D tensor
        of shape (batch, n_boxes_total).
    References:
        https://arxiv.org/abs/1504.08083
    '''
    absolute_loss = tf.abs(y_true - y_pred)
    square_loss = 0.5 * (y_true - y_pred)**2
    l1_loss = tf.where(tf.less(absolute_loss, 1.0), square_loss, absolute_loss - 0.5)
    return tf.reduce_sum(l1_loss, axis=-1)

# %%
class SSDLoss:
    '''
    The SSD loss, see https://arxiv.org/abs/1512.02325.
    '''

    def __init__(self,
                 neg_pos_ratio=3,
                 n_neg_min=0,
                 alpha=1.0):
        
        self.neg_pos_ratio = neg_pos_ratio
        self.n_neg_min = n_neg_min
        self.alpha = alpha

    def compute_loss(self, y_true, y_pred):
        neg_pos_ratio = tf.constant(3)
        n_neg_min = tf.constant(0)
        alpha = tf.constant(1)

        batch_size = tf.shape(y_pred)[0]
        n_boxes = tf.shape(y_pred)[1]

        classification_loss = binary_focal_loss_fixed(y_true[:,:,0], y_pred[:,:,0])
        localization_loss = smooth_L1_loss(y_true[:,:,1:], y_pred[:,:,1:])

        negatives = y_true[:,:,0]
        negatives = -(negatives-1)
        positives = y_true[:,:,0]
        n_positive = tf.reduce_sum(positives)


        pos_class_loss = tf.reduce_sum(classification_loss * positives, axis=-1)
        neg_class_loss_all =  classification_loss * negatives
        n_neg_losses = tf.math.count_nonzero(neg_class_loss_all, dtype=tf.int32)
        n_negative_keep = tf.minimum(tf.cast(tf.maximum(3 * n_positive, 1), tf.int32), n_neg_losses)
        def f1():
            return tf.zeros([batch_size])
        def f2():
            neg_class_loss_all_1D = tf.reshape(neg_class_loss_all, [-1])
            values, indices = tf.nn.top_k(tf.cast(neg_class_loss_all_1D, tf.int32), k=tf.cast(n_negative_keep, tf.int32), sorted=False)
            negatives_keep = tf.scatter_nd(indices=tf.expand_dims(indices, axis=1), updates=tf.ones_like(indices, dtype=tf.int32), shape=tf.shape(neg_class_loss_all_1D))
            negatives_keep = tf.reshape(negatives_keep, [batch_size, n_boxes])
            neg_class_loss = tf.reduce_sum(classification_loss * tf.cast(negatives_keep, tf.float32), axis=-1)
            return neg_class_loss

        neg_class_loss = tf.cond(tf.equal(n_neg_losses, tf.constant(0)), f1, f2)

        class_loss = pos_class_loss + neg_class_loss
        loc_loss = tf.reduce_sum(localization_loss * positives, axis=-1) # Tensor of shape (batch_size,)
        total_loss = (class_loss + loc_loss) / tf.maximum(1.0,  tf.cast(n_positive, tf.float32)) # In case `n_positive == 0`
        
        # total_loss = total_loss * tf.to_float(batch_size)

        return total_loss

# %%
loss = SSDLoss()

# %%
loss.compute_loss(y_true_batch, y_pred).numpy().max()
# Out:
# 36.870594

# %% [markdown]
# ## Training

# %%
def area(boxes):
    return (boxes[:, 2] - boxes[:, 0]) * (boxes[:, 3] - boxes[:, 1])

def intersection(boxes1, boxes2):
    [y_min1, x_min1, y_max1, x_max1] = np.split(boxes1, 4, axis=1)
    [y_min2, x_min2, y_max2, x_max2] = np.split(boxes2, 4, axis=1)
    all_pairs_min_ymax = np.minimum(y_max1, np.transpose(y_max2))
    all_pairs_max_ymin = np.maximum(y_min1, np.transpose(y_min2))
    intersect_heights = np.maximum(np.zeros(all_pairs_max_ymin.shape), all_pairs_min_ymax - all_pairs_max_ymin)
    all_pairs_min_xmax = np.minimum(x_max1, np.transpose(x_max2))
    all_pairs_max_xmin = np.maximum(x_min1, np.transpose(x_min2))
    intersect_widths = np.maximum(np.zeros(all_pairs_max_xmin.shape), all_pairs_min_xmax - all_pairs_max_xmin)
    return intersect_heights * intersect_widths


def iou(boxes1, boxes2):
    """
    boxes1 and boxes2 should be in the same scale and corner format
    """
    intersect = intersection(boxes1, boxes2)
    area1 = area(boxes1)
    area2 = area(boxes2)
    union = np.expand_dims(area1, axis=1) + np.expand_dims(area2, axis=0) - intersect
    return intersect / union

def center_to_corner(center_boxes):
    """
    (cx, cy, w, h) to (y1, x1, y2, x2)
    """
    corner_boxes = np.zeros(center_boxes.shape)
    corner_boxes[:,:2] = center_boxes[:,:2] - center_boxes[:,2:] / 2
    corner_boxes[:,2:] = corner_boxes[:,:2] + center_boxes[:,2:]
    return corner_boxes

def corner_to_center(corner_boxes):
    """
    (x1, y1, x2, y2) to (cx, cy, w, h)
    """
    center_boxes = np.zeros(corner_boxes.shape)
    center_boxes[:,:2] = (corner_boxes[:,:2] + corner_boxes[:,2:]) / 2
    center_boxes[:,2:] = corner_boxes[:,2:] - corner_boxes[:,:2]
    return center_boxes

def match(annotation, anchors, match_threshold=0.5):
    """Match each prior box with the ground truth box of the highest jaccard
    overlap, encode the bounding boxes, then return the matched indices
    corresponding to both confidence and location preds.
    Args:
        match_threshold: (float) The overlap threshold used when mathing boxes. default=0.5
        annotation: (list) Ground truth labels and ground truth boxes, Shape: [(num_obj, 1), (num_obj, num_coordinate)].
        anchors: (np.array) Anchor boxes Shape: [n_priors,4].
        loc_truth: (tensor) Tensor to be filled w/ endcoded location targets.
        conf_truth: (tensor) Tensor to be filled w/ matched indices for conf preds.
        batch_id: (int) current batch index
    Return:
        The matched indices corresponding to 1)location and 2)confidence preds.
    """
    # jaccard index
    ious = iou(annotation[1][:, :4], center_to_corner(anchors))
    best_prior_overlap, best_prior_idx = np.max(ious, 1), np.argmax(ious, 1)
    # [1,num_priors] best ground truth for each prior
    best_truth_overlap, best_truth_idx = np.max(ious, 0), np.argmax(ious, 0)
    best_truth_idx.squeeze()
    best_truth_overlap.squeeze()
    best_prior_idx.squeeze()
    best_prior_overlap.squeeze()
    best_truth_overlap[best_prior_idx] = 2
    for j in range(len(best_prior_idx)):
        best_truth_idx[best_prior_idx[j]] = j
    matches = annotation[1][best_truth_idx]
    
    # Shape: [num_priors]    
    conf = annotation[0][best_truth_idx]         
    # label as background
    conf[best_truth_overlap < match_threshold] = 0  
    loc = encode(matches, anchors)
    
    # [num_priors,4] encoded offsets to learn
    # loc_truth[batch_id] = encoded_loc
    # [num_priors] top class label for each prior
    # conf_truth[batch_id] = conf
    return conf, loc

def encode(matches, anchors):
    """Encode the variances from the priorbox layers into the ground truth boxes
    we have matched (based on jaccard overlap) with the prior boxes.
    Args:
        matches: (tensor) Coords of ground truth for each prior in point-form Shape: [num_priors, 18].
        anchors: (tensor) Prior boxes in center-offset form Shape: [num_priors, 18].
    Return:
        encoded location (tensor), Shape: [num_priors, 18]
    """

    # dist b/t match center and prior's center
    # (x_min, y_min, x_max, y_max) to (center)
    g_cxcy = corner_to_center(matches[:, :4])[:,:2] - anchors[:, :2]   
    g_wh = (matches[:, 2:4] - matches[:, :2])
    g_kp = matches[:, 4:].reshape(-1, 7, 2) - anchors[:, :2].reshape(-1, 1, 2)    

    return np.concatenate([g_cxcy, g_wh, g_kp.reshape(-1, 14)], 1)  # [num_priors, 18]

# %%
def binary_focal_loss_fixed(y_true, y_pred):
    """
    :param y_true: A tensor of the same shape as `y_pred`
    :param y_pred:  A tensor resulting from a sigmoid
    :return: Output tensor.
    """
    gamma=2.
    alpha=.25
    y_true = tf.cast(y_true, tf.float32)
    # Define epsilon so that the back-propagation will not result in NaN for 0 divisor case
    epsilon = tf.keras.backend.epsilon()
    # Add the epsilon to prediction value
    # y_pred = y_pred + epsilon
    # Clip the prediciton value
    y_pred = tf.keras.backend.clip(y_pred, epsilon, 1.0 - epsilon)
    # Calculate p_t
    p_t = tf.where(tf.keras.backend.equal(y_true, 1), y_pred, 1 - y_pred)
    # Calculate alpha_t
    alpha_factor = tf.keras.backend.ones_like(y_true) * alpha
    alpha_t = tf.where(tf.keras.backend.equal(y_true, 1), alpha_factor, 1 - alpha_factor)
    # Calculate cross entropy
    cross_entropy = -tf.math.log(p_t)
    weight = alpha_t * tf.math.pow((1 - p_t), gamma)
    # Calculate focal loss
    loss = weight * cross_entropy
    # Sum the losses in mini_batch
#     loss = tf.keras.backend.mean(tf.keras.backend.sum(loss, axis=1))
    return loss

def smooth_L1_loss(y_true, y_pred):
    '''
    Compute smooth L1 loss, see references.
    Arguments:
        y_true (nD tensor): A TensorFlow tensor of any shape containing the ground truth data.
            In this context, the expected tensor has shape `(batch_size, #boxes, 4)` and
            contains the ground truth bounding box coordinates, where the last dimension
            contains `(xmin, xmax, ymin, ymax)`.
        y_pred (nD tensor): A TensorFlow tensor of identical structure to `y_true` containing
            the predicted data, in this context the predicted bounding box coordinates.
    Returns:
        The smooth L1 loss, a nD-1 Tensorflow tensor. In this context a 2D tensor
        of shape (batch, n_boxes_total).
    References:
        https://arxiv.org/abs/1504.08083
    '''
    absolute_loss = tf.abs(y_true - y_pred)
    square_loss = 0.5 * (y_true - y_pred)**2
    l1_loss = tf.where(tf.less(absolute_loss, 1.0), square_loss, absolute_loss - 0.5)
    return tf.reduce_sum(l1_loss, axis=-1)

# %%
class SSDLoss:
    '''
    The SSD loss, see https://arxiv.org/abs/1512.02325.
    '''

    def __init__(self,
                 neg_pos_ratio=3,
                 n_neg_min=0,
                 alpha=1.0):
        
        self.neg_pos_ratio = neg_pos_ratio
        self.n_neg_min = n_neg_min
        self.alpha = alpha

    def compute_loss(self, y_true, y_pred):
        neg_pos_ratio = tf.constant(3)
        n_neg_min = tf.constant(0)
        alpha = tf.constant(1)

        batch_size = tf.shape(y_pred)[0]
        n_boxes = tf.shape(y_pred)[1]

        classification_loss = binary_focal_loss_fixed(y_true[:,:,0], y_pred[:,:,0])
        localization_loss = smooth_L1_loss(y_true[:,:,1:], y_pred[:,:,1:])

        negatives = y_true[:,:,0]
        negatives = -(negatives-1)
        positives = y_true[:,:,0]
        n_positive = tf.reduce_sum(positives)


        pos_class_loss = tf.reduce_sum(classification_loss * positives, axis=-1)
        neg_class_loss_all =  classification_loss * negatives
        n_neg_losses = tf.math.count_nonzero(neg_class_loss_all, dtype=tf.int32)
        n_negative_keep = tf.minimum(tf.cast(tf.maximum(3 * n_positive, 1), tf.int32), n_neg_losses)
        def f1():
            return tf.zeros([batch_size])
        def f2():
            neg_class_loss_all_1D = tf.reshape(neg_class_loss_all, [-1])
            values, indices = tf.nn.top_k(tf.cast(neg_class_loss_all_1D, tf.int32), k=tf.cast(n_negative_keep, tf.int32), sorted=False)
            negatives_keep = tf.scatter_nd(indices=tf.expand_dims(indices, axis=1), updates=tf.ones_like(indices, dtype=tf.int32), shape=tf.shape(neg_class_loss_all_1D))
            negatives_keep = tf.reshape(negatives_keep, [batch_size, n_boxes])
            neg_class_loss = tf.reduce_sum(classification_loss * tf.cast(negatives_keep, tf.float32), axis=-1)
            return neg_class_loss

        neg_class_loss = tf.cond(tf.equal(n_neg_losses, tf.constant(0)), f1, f2)

        class_loss = pos_class_loss + neg_class_loss
        loc_loss = tf.reduce_sum(localization_loss * positives, axis=-1) # Tensor of shape (batch_size,)
        total_loss = (class_loss + loc_loss) / tf.maximum(1.0,  tf.cast(n_positive, tf.float32)) # In case `n_positive == 0`
        
        # total_loss = total_loss * tf.to_float(batch_size)

        return total_loss

# %%
def preprocess(bgr_image, w, h):
    # convert to rgb
    rgb_image = bgr_image[:, :, ::-1]
    # pad to square and resize
    shape = np.r_[rgb_image.shape]
    padding = (shape.max() - shape[:2]).astype('uint32') // 2
    rgb_image = np.pad(rgb_image, ((padding[0], padding[0]), (padding[1], padding[1]), (0, 0)), mode='constant')
    rgb_image = cv2.resize(rgb_image, (w, h))
    rgb_image = np.ascontiguousarray(rgb_image)
    # normalize
    rgb_image = np.ascontiguousarray(2 * ((rgb_image / 255) - 0.5).astype('float32'))
    # reshape as input shape
    rgb_image = rgb_image[tf.newaxis, ...]
    return rgb_image, padding

# %%
anchor_config = AnchorsConfig(fixed_anchor_size=False)
anchor_generator = AnchorsGenerator(anchor_config)
anchors = anchor_generator.generate()
anchors_normalized = np.array([[anchor.x_center,anchor.y_center, anchor.w, anchor.h] for anchor in anchors])

# %%
model = blaze_palm.build_blaze_palm_model()

# %% [markdown]
# Create fake training data x_true

# %%
image = np.random.random((480, 640, 3))
input_image, _ = preprocess(image, 256, 256)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image)
plt.subplot(122)
plt.imshow(input_image[0])
plt.show()
x_data = np.array([input_image[0], ] * 1000)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# annotation y_true

# %%
ground_truth_labels = np.array([[1]])
ground_truth_box = np.array([129.64256-60.13495/2, 153.4913-60.13495/2, 129.64256+60.13495/2, 153.4913+60.13495/2, 136.83605957, 177.14094543, 118.33981323, 127.28881073, 130.82832336, 126.52574158, 142.27386475, 131.28793335, 152.84526062, 137.67770386, 119.28163147, 173.47927856, 105.67642212, 152.75184631]).reshape(1, -1)
annotation = [ground_truth_labels, ground_truth_box/256]

# %%
num_anchors = 2944
num_coordinates = 18
num_key_points = 7
num_classes = 1
positive_threshold = 0.5
negative_threshold = 0.5

# %%
annotation[1].shape
# Out:
# (1, 18)

# %%
y_data = np.zeros((1000, num_anchors, num_classes+num_coordinates))
for i in range(1000):
    conf, loc = match(annotation, anchors_normalized, match_threshold=0.5)
    y_data[i] = np.concatenate([conf, loc * 256], axis=-1)

# %%
y_data.shape
# Out:
# (1000, 2944, 19)

# %%
adam = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss()
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
history = model.fit(x=x_data, y=y_data, steps_per_epoch=10, epochs=10, batch_size=4)
# Out:
# Train on 1000 samples
# Epoch 1/10
#    4/1000 [..............................] - ETA: 23:21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-933a66c125e9> in <module>
# ----> 1 history = model.fit(x=x_data, y=y_data, steps_per_epoch=10, epochs=10, batch_size=4)
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     518         # Lifting succeeded, so variables are initialized and we can run the
#     519         # stateless function.
# --> 520         return self._stateless_fn(*args, **kwds)
#     521     else:
#     522       canon_args, canon_kwds = \
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1820   def __call__(self, *args, **kwargs):
#    1821     """Calls a graph function specialized to the inputs."""
# -> 1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    2148         graph_function = self._function_cache.primary.get(cache_key, None)
#    2149         if graph_function is None:
# -> 2150           graph_function = self._create_graph_function(args, kwargs)
#    2151           self._function_cache.primary[cache_key] = graph_function
#    2152         return graph_function, args, kwargs
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2039             arg_names=arg_names,
#    2040             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2041             capture_by_value=self._capture_by_value),
#    2042         self._function_attributes,
#    2043         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     913                                           converted_func)
#     914
# --> 915       func_outputs = python_func(*func_args, **func_kwargs)
#     916
#     917       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     356         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     357         # the function a weak reference to itself to avoid a reference cycle.
# --> 358         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     359     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     360
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in distributed_function(input_iterator)
#      71     strategy = distribution_strategy_context.get_strategy()
#      72     outputs = strategy.experimental_run_v2(
# ---> 73         per_replica_function, args=(model, x, y, sample_weights))
#      74     # Out of PerReplica outputs reduce or pick values to return.
#      75     all_outputs = dist_utils.unwrap_output_dict(
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in experimental_run_v2(self, fn, args, kwargs)
#     758       fn = autograph.tf_convert(fn, ag_ctx.control_status_ctx(),
#     759                                 convert_by_default=False)
# --> 760       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     761
#     762   def reduce(self, reduce_op, value, axis):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    1785       kwargs = {}
#    1786     with self._container_strategy().scope():
# -> 1787       return self._call_for_each_replica(fn, args, kwargs)
#    1788
#    1789   def _call_for_each_replica(self, fn, args, kwargs):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    2130         self._container_strategy(),
#    2131         replica_id_in_sync_group=constant_op.constant(0, dtypes.int32)):
# -> 2132       return fn(*args, **kwargs)
#    2133
#    2134   def _reduce_to(self, reduce_op, value, destinations):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     290   def wrapper(*args, **kwargs):
#     291     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 292       return func(*args, **kwargs)
#     293
#     294   if inspect.isfunction(func) or inspect.ismethod(func):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     270                         loss_scale_optimizer.LossScaleOptimizer):
#     271             grads = model.optimizer.get_unscaled_gradients(grads)
# --> 272           model.optimizer.apply_gradients(zip(grads, trainable_weights))
#     273       else:
#     274         logging.warning('The list of trainable weights is empty. Make sure that'
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py in apply_gradients(self, grads_and_vars, name)
#     439           functools.partial(self._distributed_apply, apply_state=apply_state),
#     440           args=(grads_and_vars,),
# --> 441           kwargs={"name": name})
#     442
#     443   def _distributed_apply(self, distribution, grads_and_vars, name, apply_state):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in merge_call(self, merge_fn, args, kwargs)
#    1915     if kwargs is None:
#    1916       kwargs = {}
# -> 1917     return self._merge_call(merge_fn, args, kwargs)
#    1918
#    1919   def _merge_call(self, merge_fn, args, kwargs):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py in _merge_call(self, merge_fn, args, kwargs)
#    1922         distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    1923     try:
# -> 1924       return merge_fn(self._strategy, *args, **kwargs)
#    1925     finally:
#    1926       _pop_per_thread_mode()
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py in _distributed_apply(self, distribution, grads_and_vars, name, apply_state)
#     480         # delays. See b/136304694.
#     481         with backend.name_scope(
# --> 482             scope_name), distribution.extended.colocate_vars_with(var):
#     483           update_ops.extend(
#     484               distribution.extended.update(
#
# ~\AppData\Local\Programs\Python\Python36\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in _colocate_with_for_gradient(self, op, gradient_uid, ignore_existing)
#    4218   def _colocate_with_for_gradient(self, op, gradient_uid,
#    4219                                   ignore_existing=False):
# -> 4220     with self.colocate_with(op, ignore_existing):
#    4221       if gradient_uid is not None and self._control_flow_context is not None:
#    4222         self._control_flow_context.EnterGradientColocation(op, gradient_uid)
#
# ~\AppData\Local\Programs\Python\Python36\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in colocate_with(self, op, ignore_existing)
#    4267       raise ValueError("Trying to reset colocation (op is None) but "
#    4268                        "ignore_existing is not True")
# -> 4269     op = _op_to_colocate_with(op, self)
#    4270
#    4271     # By default, colocate_with resets the device function stack,
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in _op_to_colocate_with(v, graph)
#    6607     else:
#    6608       return v.handle.op
# -> 6609   return internal_convert_to_tensor_or_indexed_slices(v, as_ref=True).op
#    6610
#    6611
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py in internal_convert_to_tensor_or_indexed_slices(value, dtype, name, as_ref)
#     307   else:
#     308     return ops.internal_convert_to_tensor(
# --> 309         value, dtype=dtype, name=name, as_ref=as_ref)
#     310
#     311
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_composite_tensors)
#    1294
#    1295     if ret is None:
# -> 1296       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1297
#    1298     if ret is NotImplemented:
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in _dense_var_to_tensor(var, dtype, name, as_ref)
#    1787
#    1788 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 1789   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)  # pylint: disable=protected-access
#    1790
#    1791
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in _dense_var_to_tensor(***failed resolving arguments***)
#    1210           "of type {!r}".format(dtype.name, self.dtype.name))
#    1211     if as_ref:
# -> 1212       return self.read_value().op.inputs[0]
#    1213     else:
#    1214       return self.value()
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in read_value(self)
#     631     # Return an identity so it can get placed on whatever device the context
#     632     # specifies instead of the device where the variable is.
# --> 633     return array_ops.identity(value)
#     634
#     635   def sparse_read(self, indices, name=None):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     212       return copied
#     213   else:
# --> 214     ret = gen_array_ops.identity(input, name=name)
#     215     # Propagate handle data for happier shape inference for resource variables.
#     216     if hasattr(input, "_handle_data"):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    4236   # Add nodes to the TensorFlow graph.
#    4237   _, _, _op = _op_def_lib._apply_op_helper(
# -> 4238         "Identity", input=input, name=name)
#    4239   _result = _op.outputs[:]
#    4240   _inputs_flat = _op.inputs
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     791         op = g.create_op(op_type_name, inputs, dtypes=None, name=scope,
#     792                          input_types=input_types, attrs=attr_protos,
# --> 793                          op_def=op_def)
#     794       return output_structure, op_def.is_stateful, op
#     795
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\func_graph.py in create_op(***failed resolving arguments***)
#     546     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     547         op_type, inputs, dtypes, input_types, name, attrs, op_def,
# --> 548         compute_device)
#     549
#     550   def capture(self, tensor, name=None):
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3427           input_types=input_types,
#    3428           original_op=self._default_original_op,
# -> 3429           op_def=op_def)
#    3430       self._create_op_helper(ret, compute_device=compute_device)
#    3431     return ret
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1771           op_def, inputs, node_def.attr)
#    1772       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1773                                 control_input_ops)
#    1774     # pylint: enable=protected-access
#    1775
#
# d:\my_space\mediapipe_blaze_palm\venv\lib\site-packages\tensorflow_core\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1585   # pylint: disable=protected-access
#    1586   op_desc = c_api.TF_NewOperation(graph._c_graph, compat.as_str(node_def.op),
# -> 1587                                   compat.as_str(node_def.name))
#    1588   if node_def.device:
#    1589     c_api.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test Model

# %%
pred = model.predict(input_image)

# %%
def sigmoid(values):
    return 1/(1+np.exp(-values))

# %%
output_clf = pred[:,:,0][0]
scores = sigmoid(output_clf)

# %%
output_reg = pred[:,:,1:][0]

# %%
output_reg = output_reg[scores>0.9999999]
output_clf = output_clf[scores>0.9999999]
candidate_anchors = anchors_normalized[scores>0.9999999]

# %%
moved_output_reg = output_reg.copy()
moved_output_reg[:, :2] = moved_output_reg[:, :2] + candidate_anchors[:, :2] * 256

# %%
def non_max_suppression_fast(boxes, probabilities=None, overlap_threshold=0.3):
    """
    Algorithm to filter bounding box proposals by removing the ones with a too low confidence score
    and with too much overlap.
    Source: https://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
    :param boxes: List of proposed bounding boxes
    :param overlap_threshold: the maximum overlap that is allowed
    :return: filtered boxes
    """
    # if there are no boxes, return an empty list
    if boxes.shape[1] == 0:
        return []
    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")
    # initialize the list of picked indexes
    pick = []
    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0] - (boxes[:, 2] / [2])  # center x - width/2
    y1 = boxes[:, 1] - (boxes[:, 3] / [2])  # center y - height/2
    x2 = boxes[:, 0] + (boxes[:, 2] / [2])  # center x + width/2
    y2 = boxes[:, 1] + (boxes[:, 3] / [2])  # center y + height/2

    # compute the area of the bounding boxes and grab the indexes to sort
    # (in the case that no probabilities are provided, simply sort on the
    # bottom-left y-coordinate)
    area = boxes[:, 2] * boxes[:, 3]  # width * height
    idxs = y2


    # if probabilities are provided, sort on them instead
    if probabilities is not None:
        idxs = probabilities

    # sort the indexes
    idxs = np.argsort(idxs)
    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)
        # find the largest (x, y) coordinates for the start of
        # the bounding box and the smallest (x, y) coordinates
        # for the end of the bounding box
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])
        # compute the width and height of the bounding box
        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)
        # compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]
        # delete all indexes from the index list that have
        idxs = np.delete(idxs, np.concatenate(([last],
                                               np.where(overlap > overlap_threshold)[0])))
    # return only the bounding boxes that were picked
    return pick

# %%
box_ids = non_max_suppression_fast(moved_output_reg[:, :4], output_clf)

# %%
center_wo_offst = candidate_anchors[box_ids,:2] * 256
bboxes = moved_output_reg[box_ids, :4].astype('int')
keypoints_set = output_reg[box_ids,4:].reshape(-1, 7, 2)
for i in range(len(keypoints_set)):
    keypoints_set[i] = keypoints_set[i] + center_wo_offst[i]

# %%
color = ['limegreen', 'r']
width = [3, 3]
style = ['-', '--']
alpha = [1, 0.5]


plt.figure(figsize=(7, 7))
plt.title("Result")
result_image = input_image.copy()[0]

x1, y1, x2, y2 = annotation[1][:,:4][0]*256
rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[0], ec=color[0], ls=style[0], alpha=alpha[0], facecolor="none", label='Ground Truth')
plt.gca().add_patch(rect)
# plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[0], s=87)
for key_point in annotation[1][0,4:].reshape(-1,2)*256:
    plt.scatter(key_point[0], key_point[1], color=color[0], s=40)
    
for i in range(len(bboxes)):
    cx, cy, w, h = bboxes[i][:4]
    x1, y1, x2, y2 = (cx-w//2, cy-h//2, cx+w//2, cy+h//2)
    if i == 0:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[1], ec=color[1], ls=style[1], alpha=alpha[1], facecolor="none", label='Prediction')
    else:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[1], ec=color[1], ls=style[1], alpha=alpha[1], facecolor="none")
    plt.gca().add_patch(rect)
#     plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[1], s=87)
    for key_point in keypoints_set[i]:
        plt.scatter(key_point[0], key_point[1], color=color[1], s=40)

plt.legend()
plt.imshow(result_image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pred_id = np.argmax(pred[0,:,0])
pred_loc = pred[0,:,1:][pred_id]
pred_loc[:2] = anchors_normalized[pred_id,:2]*256 + pred_loc[:2]
pred_loc[:4] = center_to_corner(np.array([pred_loc[:4]]))
pred_loc[4:] = (pred_loc[4:].reshape(-1, 2) + anchors_normalized[pred_id,:2]*256).reshape(-1)

# %%
color = ['limegreen', 'r']
width = [3, 3]
style = ['-', '--']
alpha = [1, 0.5]


plt.figure(figsize=(7, 7))
plt.title("Result")
result_image = input_image.copy()[0]

x1, y1, x2, y2 = annotation[1][:,:4][0]*256
rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[0], ec=color[0], ls=style[0], alpha=alpha[0], facecolor="none", label='Ground Truth')
plt.gca().add_patch(rect)
plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[0], s=87)
for key_point in annotation[1][0,4:].reshape(-1,2)*256:
    plt.scatter(key_point[0], key_point[1], color=color[0], s=40)
    

x1, y1, x2, y2 = pred_loc[:4]
rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[1], ec=color[1], ls=style[1], alpha=alpha[1], facecolor="none", label='Prediction')
plt.gca().add_patch(rect)
plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[1], s=87)
for key_point in pred_loc[4:].reshape(-1, 2):
    plt.scatter(key_point[0], key_point[1], color=color[1], s=40)

plt.legend()
plt.imshow(result_image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
