# %% [markdown]
# # Train BlazePalm Model

# %%
import os
import glob
import json

import tensorflow as tf
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from utils import anchors_generator, encoder, loss_function
from nets import blaze_palm 
from utils.data_generator import DataGenerator

# %%
tf.__version__
# Out:
# '2.7.0'

# %% [markdown]
# ## Create BlazePalm Model

# %%
model = blaze_palm.build_blaze_palm_model()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['conv2d[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 128, 128, 32  320        ['activation[0][0]']
#  v2D)                           )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  1056        ['depthwise_conv2d[0][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 32  0           ['conv2d_1[0][0]',
#                                 )                                 'activation[0][0]']
#
#  activation_1 (Activation)      (None, 128, 128, 32  0           ['add[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 128, 128, 32  320        ['activation_1[0][0]']
#  onv2D)                         )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  1056        ['depthwise_conv2d_1[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 128, 128, 32  0           ['conv2d_2[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 128, 128, 32  0           ['add_1[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 128, 128, 32  320        ['activation_2[0][0]']
#  onv2D)                         )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  1056        ['depthwise_conv2d_2[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 32  0           ['conv2d_3[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['add_2[0][0]']
#                                 )
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 128, 128, 32  320        ['activation_3[0][0]']
#  onv2D)                         )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  1056        ['depthwise_conv2d_3[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 128, 128, 32  0           ['conv2d_4[0][0]',
#                                 )                                 'activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 128, 128, 32  0           ['add_3[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 128, 128, 32  320        ['activation_4[0][0]']
#  onv2D)                         )
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 32  1056        ['depthwise_conv2d_4[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 128, 128, 32  0           ['conv2d_5[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 128, 128, 32  0           ['add_4[0][0]']
#                                 )
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 128, 128, 32  320        ['activation_5[0][0]']
#  onv2D)                         )
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 32  1056        ['depthwise_conv2d_5[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 128, 128, 32  0           ['conv2d_6[0][0]',
#                                 )                                 'activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 128, 128, 32  0           ['add_5[0][0]']
#                                 )
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 128, 128, 32  320        ['activation_6[0][0]']
#  onv2D)                         )
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 32  1056        ['depthwise_conv2d_6[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 128, 128, 32  0           ['conv2d_7[0][0]',
#                                 )                                 'activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 128, 128, 32  0           ['add_6[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['activation_7[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 64, 64, 32)  320         ['activation_7[0][0]']
#  onv2D)
#
#  tf.zeros_like (TFOpLambda)     (None, 64, 64, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 64)   2112        ['depthwise_conv2d_7[0][0]']
#
#  tf.concat (TFOpLambda)         (None, 64, 64, 64)   0           ['max_pooling2d[0][0]',
#                                                                   'tf.zeros_like[0][0]']
#
#  add_7 (Add)                    (None, 64, 64, 64)   0           ['conv2d_8[0][0]',
#                                                                   'tf.concat[0][0]']
#
#  activation_8 (Activation)      (None, 64, 64, 64)   0           ['add_7[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 64, 64, 64)  640         ['activation_8[0][0]']
#  onv2D)
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 64)   4160        ['depthwise_conv2d_8[0][0]']
#
#  add_8 (Add)                    (None, 64, 64, 64)   0           ['conv2d_9[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 64, 64, 64)   0           ['add_8[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 64, 64, 64)  640         ['activation_9[0][0]']
#  onv2D)
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 64)   4160        ['depthwise_conv2d_9[0][0]']
#
#  add_9 (Add)                    (None, 64, 64, 64)   0           ['conv2d_10[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 64, 64, 64)   0           ['add_9[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 64, 64, 64)  640         ['activation_10[0][0]']
#  Conv2D)
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 64)   4160        ['depthwise_conv2d_10[0][0]']
#
#  add_10 (Add)                   (None, 64, 64, 64)   0           ['conv2d_11[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 64, 64, 64)   0           ['add_10[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 64, 64, 64)  640         ['activation_11[0][0]']
#  Conv2D)
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   4160        ['depthwise_conv2d_11[0][0]']
#
#  add_11 (Add)                   (None, 64, 64, 64)   0           ['conv2d_12[0][0]',
#                                                                   'activation_11[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 64)   0           ['add_11[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (None, 64, 64, 64)  640         ['activation_12[0][0]']
#  Conv2D)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   4160        ['depthwise_conv2d_12[0][0]']
#
#  add_12 (Add)                   (None, 64, 64, 64)   0           ['conv2d_13[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 64, 64, 64)   0           ['add_12[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (None, 64, 64, 64)  640         ['activation_13[0][0]']
#  Conv2D)
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   4160        ['depthwise_conv2d_13[0][0]']
#
#  add_13 (Add)                   (None, 64, 64, 64)   0           ['conv2d_14[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 64, 64, 64)   0           ['add_13[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 64, 64, 64)  640         ['activation_14[0][0]']
#  Conv2D)
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   4160        ['depthwise_conv2d_14[0][0]']
#
#  add_14 (Add)                   (None, 64, 64, 64)   0           ['conv2d_15[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['add_14[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['activation_15[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 32, 32, 64)  640         ['activation_15[0][0]']
#  Conv2D)
#
#  tf.zeros_like_1 (TFOpLambda)   (None, 32, 32, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 128)  8320        ['depthwise_conv2d_15[0][0]']
#
#  tf.concat_1 (TFOpLambda)       (None, 32, 32, 128)  0           ['max_pooling2d_1[0][0]',
#                                                                   'tf.zeros_like_1[0][0]']
#
#  add_15 (Add)                   (None, 32, 32, 128)  0           ['conv2d_16[0][0]',
#                                                                   'tf.concat_1[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 128)  0           ['add_15[0][0]']
#
#  depthwise_conv2d_16 (Depthwise  (None, 32, 32, 128)  1280       ['activation_16[0][0]']
#  Conv2D)
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_16[0][0]']
#
#  add_16 (Add)                   (None, 32, 32, 128)  0           ['conv2d_17[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 128)  0           ['add_16[0][0]']
#
#  depthwise_conv2d_17 (Depthwise  (None, 32, 32, 128)  1280       ['activation_17[0][0]']
#  Conv2D)
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_17[0][0]']
#
#  add_17 (Add)                   (None, 32, 32, 128)  0           ['conv2d_18[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 128)  0           ['add_17[0][0]']
#
#  depthwise_conv2d_18 (Depthwise  (None, 32, 32, 128)  1280       ['activation_18[0][0]']
#  Conv2D)
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_18[0][0]']
#
#  add_18 (Add)                   (None, 32, 32, 128)  0           ['conv2d_19[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 128)  0           ['add_18[0][0]']
#
#  depthwise_conv2d_19 (Depthwise  (None, 32, 32, 128)  1280       ['activation_19[0][0]']
#  Conv2D)
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_19[0][0]']
#
#  add_19 (Add)                   (None, 32, 32, 128)  0           ['conv2d_20[0][0]',
#                                                                   'activation_19[0][0]']
#
#  activation_20 (Activation)     (None, 32, 32, 128)  0           ['add_19[0][0]']
#
#  depthwise_conv2d_20 (Depthwise  (None, 32, 32, 128)  1280       ['activation_20[0][0]']
#  Conv2D)
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_20[0][0]']
#
#  add_20 (Add)                   (None, 32, 32, 128)  0           ['conv2d_21[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 32, 32, 128)  0           ['add_20[0][0]']
#
#  depthwise_conv2d_21 (Depthwise  (None, 32, 32, 128)  1280       ['activation_21[0][0]']
#  Conv2D)
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_21[0][0]']
#
#  add_21 (Add)                   (None, 32, 32, 128)  0           ['conv2d_22[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 32, 32, 128)  0           ['add_21[0][0]']
#
#  depthwise_conv2d_22 (Depthwise  (None, 32, 32, 128)  1280       ['activation_22[0][0]']
#  Conv2D)
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_22[0][0]']
#
#  add_22 (Add)                   (None, 32, 32, 128)  0           ['conv2d_23[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_23 (Activation)     (None, 32, 32, 128)  0           ['add_22[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['activation_23[0][0]']
#
#  depthwise_conv2d_23 (Depthwise  (None, 16, 16, 128)  1280       ['activation_23[0][0]']
#  Conv2D)
#
#  tf.zeros_like_2 (TFOpLambda)   (None, 16, 16, 128)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 256)  33024       ['depthwise_conv2d_23[0][0]']
#
#  tf.concat_2 (TFOpLambda)       (None, 16, 16, 256)  0           ['max_pooling2d_2[0][0]',
#                                                                   'tf.zeros_like_2[0][0]']
#
#  add_23 (Add)                   (None, 16, 16, 256)  0           ['conv2d_24[0][0]',
#                                                                   'tf.concat_2[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 256)  0           ['add_23[0][0]']
#
#  depthwise_conv2d_24 (Depthwise  (None, 16, 16, 256)  2560       ['activation_24[0][0]']
#  Conv2D)
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_24[0][0]']
#
#  add_24 (Add)                   (None, 16, 16, 256)  0           ['conv2d_25[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 256)  0           ['add_24[0][0]']
#
#  depthwise_conv2d_25 (Depthwise  (None, 16, 16, 256)  2560       ['activation_25[0][0]']
#  Conv2D)
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_25[0][0]']
#
#  add_25 (Add)                   (None, 16, 16, 256)  0           ['conv2d_26[0][0]',
#                                                                   'activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 256)  0           ['add_25[0][0]']
#
#  depthwise_conv2d_26 (Depthwise  (None, 16, 16, 256)  2560       ['activation_26[0][0]']
#  Conv2D)
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_26[0][0]']
#
#  add_26 (Add)                   (None, 16, 16, 256)  0           ['conv2d_27[0][0]',
#                                                                   'activation_26[0][0]']
#
#  activation_27 (Activation)     (None, 16, 16, 256)  0           ['add_26[0][0]']
#
#  depthwise_conv2d_27 (Depthwise  (None, 16, 16, 256)  2560       ['activation_27[0][0]']
#  Conv2D)
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_27[0][0]']
#
#  add_27 (Add)                   (None, 16, 16, 256)  0           ['conv2d_28[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_28 (Activation)     (None, 16, 16, 256)  0           ['add_27[0][0]']
#
#  depthwise_conv2d_28 (Depthwise  (None, 16, 16, 256)  2560       ['activation_28[0][0]']
#  Conv2D)
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_28[0][0]']
#
#  add_28 (Add)                   (None, 16, 16, 256)  0           ['conv2d_29[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_29 (Activation)     (None, 16, 16, 256)  0           ['add_28[0][0]']
#
#  depthwise_conv2d_29 (Depthwise  (None, 16, 16, 256)  2560       ['activation_29[0][0]']
#  Conv2D)
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_29[0][0]']
#
#  add_29 (Add)                   (None, 16, 16, 256)  0           ['conv2d_30[0][0]',
#                                                                   'activation_29[0][0]']
#
#  activation_30 (Activation)     (None, 16, 16, 256)  0           ['add_29[0][0]']
#
#  depthwise_conv2d_30 (Depthwise  (None, 16, 16, 256)  2560       ['activation_30[0][0]']
#  Conv2D)
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_30[0][0]']
#
#  add_30 (Add)                   (None, 16, 16, 256)  0           ['conv2d_31[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 16, 16, 256)  0           ['add_30[0][0]']
#
#  depthwise_conv2d_31 (Depthwise  (None, 8, 8, 256)   2560        ['activation_31[0][0]']
#  Conv2D)
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_31[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['activation_31[0][0]']
#
#  add_31 (Add)                   (None, 8, 8, 256)    0           ['conv2d_32[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  activation_32 (Activation)     (None, 8, 8, 256)    0           ['add_31[0][0]']
#
#  depthwise_conv2d_32 (Depthwise  (None, 8, 8, 256)   2560        ['activation_32[0][0]']
#  Conv2D)
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_32[0][0]']
#
#  add_32 (Add)                   (None, 8, 8, 256)    0           ['conv2d_33[0][0]',
#                                                                   'activation_32[0][0]']
#
#  activation_33 (Activation)     (None, 8, 8, 256)    0           ['add_32[0][0]']
#
#  depthwise_conv2d_33 (Depthwise  (None, 8, 8, 256)   2560        ['activation_33[0][0]']
#  Conv2D)
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_33[0][0]']
#
#  add_33 (Add)                   (None, 8, 8, 256)    0           ['conv2d_34[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_34 (Activation)     (None, 8, 8, 256)    0           ['add_33[0][0]']
#
#  depthwise_conv2d_34 (Depthwise  (None, 8, 8, 256)   2560        ['activation_34[0][0]']
#  Conv2D)
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_34[0][0]']
#
#  add_34 (Add)                   (None, 8, 8, 256)    0           ['conv2d_35[0][0]',
#                                                                   'activation_34[0][0]']
#
#  activation_35 (Activation)     (None, 8, 8, 256)    0           ['add_34[0][0]']
#
#  depthwise_conv2d_35 (Depthwise  (None, 8, 8, 256)   2560        ['activation_35[0][0]']
#  Conv2D)
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_35[0][0]']
#
#  add_35 (Add)                   (None, 8, 8, 256)    0           ['conv2d_36[0][0]',
#                                                                   'activation_35[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 256)    0           ['add_35[0][0]']
#
#  depthwise_conv2d_36 (Depthwise  (None, 8, 8, 256)   2560        ['activation_36[0][0]']
#  Conv2D)
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_36[0][0]']
#
#  add_36 (Add)                   (None, 8, 8, 256)    0           ['conv2d_37[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 8, 8, 256)    0           ['add_36[0][0]']
#
#  depthwise_conv2d_37 (Depthwise  (None, 8, 8, 256)   2560        ['activation_37[0][0]']
#  Conv2D)
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_37[0][0]']
#
#  add_37 (Add)                   (None, 8, 8, 256)    0           ['conv2d_38[0][0]',
#                                                                   'activation_37[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 256)    0           ['add_37[0][0]']
#
#  depthwise_conv2d_38 (Depthwise  (None, 8, 8, 256)   2560        ['activation_38[0][0]']
#  Conv2D)
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 256)    65792       ['depthwise_conv2d_38[0][0]']
#
#  add_38 (Add)                   (None, 8, 8, 256)    0           ['conv2d_39[0][0]',
#                                                                   'activation_38[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 256)    0           ['add_38[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  262400     ['activation_39[0][0]']
#  ose)
#
#  activation_40 (Activation)     (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]']
#
#  add_39 (Add)                   (None, 16, 16, 256)  0           ['activation_40[0][0]',
#                                                                   'activation_31[0][0]']
#
#  depthwise_conv2d_39 (Depthwise  (None, 16, 16, 256)  2560       ['add_39[0][0]']
#  Conv2D)
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 256)  65792       ['depthwise_conv2d_39[0][0]']
#
#  add_40 (Add)                   (None, 16, 16, 256)  0           ['conv2d_40[0][0]',
#                                                                   'add_39[0][0]']
#
#  activation_41 (Activation)     (None, 16, 16, 256)  0           ['add_40[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  131200     ['activation_41[0][0]']
#  spose)
#
#  activation_42 (Activation)     (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]']
#
#  add_41 (Add)                   (None, 32, 32, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_23[0][0]']
#
#  depthwise_conv2d_40 (Depthwise  (None, 32, 32, 128)  1280       ['add_41[0][0]']
#  Conv2D)
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 128)  16512       ['depthwise_conv2d_40[0][0]']
#
#  add_42 (Add)                   (None, 32, 32, 128)  0           ['conv2d_41[0][0]',
#                                                                   'add_41[0][0]']
#
#  activation_43 (Activation)     (None, 32, 32, 128)  0           ['add_42[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 2)    258         ['activation_43[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 2)    514         ['activation_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 6)      1542        ['activation_39[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 36)   4644        ['activation_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 36)   9252        ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 108)    27756       ['activation_39[0][0]']
#
#  reshape (Reshape)              (None, 2048, 1)      0           ['conv2d_42[0][0]']
#
#  reshape_1 (Reshape)            (None, 512, 1)       0           ['conv2d_43[0][0]']
#
#  reshape_2 (Reshape)            (None, 384, 1)       0           ['conv2d_44[0][0]']
#
#  reshape_3 (Reshape)            (None, 2048, 18)     0           ['conv2d_45[0][0]']
#
#  reshape_4 (Reshape)            (None, 512, 18)      0           ['conv2d_46[0][0]']
#
#  reshape_5 (Reshape)            (None, 384, 18)      0           ['conv2d_47[0][0]']
#
#  concatenate (Concatenate)      (None, 2944, 1)      0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 2944, 18)     0           ['reshape_3[0][0]',
#                                                                   'reshape_4[0][0]',
#                                                                   'reshape_5[0][0]']
#
#  tf.concat_3 (TFOpLambda)       (None, 2944, 19)     0           ['concatenate[0][0]',
#                                                                   'concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 1,763,358
# Trainable params: 1,763,358
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
adam = tf.keras.optimizers.Adam()
ssd_loss = loss_function.SSDLoss(alpha=1./256.)
model.compile(optimizer='adam', loss=ssd_loss.compute_loss)

# %% [markdown]
# ## Prepare Data

# %%
train_data_generator = DataGenerator(image_dir=os.path.join('dataset', 'image'), batch_size=32,
                                     annotation_dir=os.path.join('dataset', 'annotation'))
val_data_generator = DataGenerator(image_dir=os.path.join('dataset', 'image'), batch_size=32,
                                     annotation_dir=os.path.join('dataset', 'annotation'))

# %%
batch = train_data_generator.__getitem__(0)
ssd_loss.compute_loss(batch[1], model.predict(batch[0]))

# %% [markdown]
# ## Training

# %% [markdown]
# > `fit_generator` not work

# %%
history = model.fit(x=train_data_generator, epochs=1000)

# %%
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'][::10], ls='--')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'])
plt.show()

# %% [markdown]
# ## Test Model

# %%
from utils.anchor_config import AnchorsConfig
from utils.anchors_generator import AnchorsGenerator
from utils.encoder import center_to_corner

# %%
def sigmoid(values):
    return 1/(1+np.exp(-values))

# %%
def non_max_suppression_fast(boxes, probabilities=None, overlap_threshold=0.3):
    """
    Algorithm to filter bounding box proposals by removing the ones with a too low confidence score
    and with too much overlap.
    Source: https://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
    :param boxes: List of proposed bounding boxes
    :param overlap_threshold: the maximum overlap that is allowed
    :return: filtered boxes
    """
    # if there are no boxes, return an empty list
    if boxes.shape[1] == 0:
        return []
    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")
    # initialize the list of picked indexes
    pick = []
    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0] - (boxes[:, 2] / [2])  # center x - width/2
    y1 = boxes[:, 1] - (boxes[:, 3] / [2])  # center y - height/2
    x2 = boxes[:, 0] + (boxes[:, 2] / [2])  # center x + width/2
    y2 = boxes[:, 1] + (boxes[:, 3] / [2])  # center y + height/2

    # compute the area of the bounding boxes and grab the indexes to sort
    # (in the case that no probabilities are provided, simply sort on the
    # bottom-left y-coordinate)
    area = boxes[:, 2] * boxes[:, 3]  # width * height
    idxs = y2


    # if probabilities are provided, sort on them instead
    if probabilities is not None:
        idxs = probabilities

    # sort the indexes
    idxs = np.argsort(idxs)
    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)
        # find the largest (x, y) coordinates for the start of
        # the bounding box and the smallest (x, y) coordinates
        # for the end of the bounding box
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])
        # compute the width and height of the bounding box
        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)
        # compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]
        # delete all indexes from the index list that have
        idxs = np.delete(idxs, np.concatenate(([last],
                                               np.where(overlap > overlap_threshold)[0])))
    # return only the bounding boxes that were picked
    return pick

# %%
def preprocess(bgr_image, w, h, normailze=True):
    # convert to rgb
    rgb_image = bgr_image[:, :, ::-1]
    # pad to square and resize
    shape = np.r_[rgb_image.shape]
    padding = (shape.max() - shape[:2]).astype('uint32') // 2
    rgb_image = np.pad(rgb_image, ((padding[0], padding[0]), (padding[1], padding[1]), (0, 0)), mode='constant')
    rgb_image = cv2.resize(rgb_image, (w, h))
    rgb_image = np.ascontiguousarray(rgb_image)
    # normalize
    if normailze:
        rgb_image = np.ascontiguousarray(2 * ((rgb_image / 255) - 0.5).astype('float32'))
    # reshape as input shape
    rgb_image = rgb_image[tf.newaxis, ...]
    return rgb_image

# %%
anchor_config = AnchorsConfig(fixed_anchor_size=False)
anchor_generator = AnchorsGenerator(anchor_config)
anchors = anchor_generator.generate()
anchors_normalized = np.array([[anchor.x_center,anchor.y_center, anchor.w, anchor.h] for anchor in anchors])

# %%
image_path = np.random.choice(glob.glob(os.path.join('dataset','image','*.jpg')))
image = preprocess(cv2.imread(image_path), 256, 256)
pred = model.predict(image)

output_clf = pred[:,:,0][0]
output_reg = pred[:,:,1:][0]
scores = sigmoid(output_clf)
t = 0.95
output_reg = output_reg[scores>t]
output_clf = output_clf[scores>t]
candidate_anchors = anchors_normalized[scores>t]

moved_output_reg = output_reg.copy()
moved_output_reg[:, :2] = moved_output_reg[:, :2] + candidate_anchors[:, :2] * 256

box_ids = non_max_suppression_fast(moved_output_reg[:, :4], output_clf)

center_wo_offst = candidate_anchors[box_ids,:2] * 256
bboxes = moved_output_reg[box_ids, :4].astype('int')
keypoints_set = output_reg[box_ids,4:].reshape(-1, 7, 2)
for i in range(len(keypoints_set)):
    keypoints_set[i] = keypoints_set[i] + center_wo_offst[i]

color = ['limegreen', 'r']
width = [3, 3]
style = ['-', '--']
alpha = [1, 0.5]


plt.figure(figsize=(7, 7))
plt.title("Result")
image_show = preprocess(cv2.imread(image_path), 256, 256, False)
result_image = image_show.copy()[0]
    
for i in range(len(bboxes)):
    cx, cy, w, h = bboxes[i][:4]
    x1, y1, x2, y2 = (cx-w//2, cy-h//2, cx+w//2, cy+h//2)
    if i == 0:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[1], ec=color[0], ls=style[0], alpha=alpha[1], facecolor="none", label='Prediction')
    else:
        rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, lw=width[1], ec=color[0], ls=style[0], alpha=alpha[1], facecolor="none")
    plt.gca().add_patch(rect)
    plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[0], s=54.87, alpha=alpha[1])
    for key_point in keypoints_set[i]:
        plt.scatter(key_point[0], key_point[1], color=color[1], s=9.487)

plt.legend()
plt.imshow(result_image)
plt.show()

# %% [markdown]
# ## Test Model

# %%
image_path = np.random.choice(glob.glob(os.path.join('dataset','image','*.jpg')))
image = preprocess(cv2.imread(image_path), 256, 256)
image_show = preprocess(cv2.imread(image_path), 256, 256, False)
# plt.imshow(image[0])

pred = model.predict(image)

pred_id = np.argmax(pred[0,:,0])
pred_loc = pred[0,:,1:][pred_id]
pred_loc[:2] = anchors_normalized[pred_id,:2]*256 + pred_loc[:2]
pred_loc[:4] = center_to_corner(np.array([pred_loc[:4]]))
pred_loc[4:] = (pred_loc[4:].reshape(-1, 2) + anchors_normalized[pred_id,:2]*256).reshape(-1)

color = ['limegreen', 'r']
width = [3, 3]
style = ['-', '--']
alpha = [1, 0.5]


plt.figure(figsize=(7, 7))
plt.title("Result")
result_image = image_show.copy()[0]    

x1, y1, x2, y2 = pred_loc[:4]
rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, 
                         lw=width[1], ec=color[0],
                         ls=style[0], alpha=alpha[1], facecolor="none", label='Prediction')
plt.gca().add_patch(rect)
for key_point in pred_loc[4:].reshape(-1, 2):
    plt.scatter(key_point[0], key_point[1], color=color[1], s=9.487)

# plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[0], alpha=alpha[1], s=87)

plt.legend()
plt.imshow(result_image)
plt.show()

# %% [markdown]
# ## Save Model

# %%
model.save('balzepalm_first_version.h5')

# %%
palm_model = tf.keras.models.load_model('model/palm.h5', custom_objects={'compute_loss': loss_function.SSDLoss(alpha=1./256.).compute_loss})

# %%
image_path = np.random.choice(glob.glob(os.path.join('dataset','image','*.jpg')))
image = preprocess(cv2.imread(image_path), 256, 256)
image_show = preprocess(cv2.imread(image_path), 256, 256, False)
# plt.imshow(image[0])

pred = palm_model.predict(image)

pred_id = np.argmax(pred[0,:,0])
pred_loc = pred[0,:,1:][pred_id]
pred_loc[:2] = anchors_normalized[pred_id,:2]*256 + pred_loc[:2]
pred_loc[:4] = center_to_corner(np.array([pred_loc[:4]]))
pred_loc[4:] = (pred_loc[4:].reshape(-1, 2) + anchors_normalized[pred_id,:2]*256).reshape(-1)

color = ['limegreen', 'r']
width = [3, 3]
style = ['-', '--']
alpha = [1, 0.5]


plt.figure(figsize=(7, 7))
plt.title("Result")
result_image = image_show.copy()[0]    

x1, y1, x2, y2 = pred_loc[:4]
rect = patches.Rectangle((x1,y1), x2-x1, y2-y1, 
                         lw=width[1], ec=color[0],
                         ls=style[0], alpha=alpha[1], facecolor="none", label='Prediction')
plt.gca().add_patch(rect)
for key_point in pred_loc[4:].reshape(-1, 2):
    plt.scatter(key_point[0], key_point[1], color=color[1], s=9.487)

# plt.scatter((x2+x1)/2, (y2+y1)/2, color=color[0], alpha=alpha[1], s=87)

plt.legend()
plt.imshow(result_image)
plt.show()
